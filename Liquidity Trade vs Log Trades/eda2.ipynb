# %%
import pandas as pd
import numpy as np

# %%
daym1 = pd.read_csv("prices_round_1_day_0.csv", sep=";")

# %%
squid = daym1[daym1['product'] == 'SQUID_INK']

# %%
erics = pd.read_csv("eric_squid.csv", sep=";")

# %%
erics_squid = erics[erics['product'] == 'SQUID_INK']

# %%
erics_squid.set_index('timestamp')['mid_price']
# Out:
# timestamp
# 0        1969.5
# 100      1970.5
# 200      1967.5
# 300      1967.5
# 400      1967.5
#           ...
# 99500    1966.5
# 99600    1966.5
# 99700    1967.5
# 99800    1968.5
# 99900    1968.5
# Name: mid_price, Length: 1000, dtype: float64

# %%
squid.set_index('timestamp')['mid_price'].iloc[:1000]
# Out:
# timestamp
# 0        1969.5
# 100      1970.0
# 200      1967.5
# 300      1966.5
# 400      1967.0
#           ...
# 99500    1966.5
# 99600    1966.5
# 99700    1967.5
# 99800    1968.5
# 99900    1968.5
# Name: mid_price, Length: 1000, dtype: float64

# %%
squid_josh = pd.read_csv("squid_ink_josh.csv", sep = ';')

# %%
squid_josh
# Out:
#       day  timestamp           product  bid_price_1  bid_volume_1  \
# 0       1          0         SQUID_INK         1834            23
# 1       1          0  RAINFOREST_RESIN         9998             9
# 2       1          0              KELP         2032            23
# 3       1        100              KELP         2034             1
# 4       1        100         SQUID_INK         1837             1
# ...   ...        ...               ...          ...           ...
# 2995    1      99800         SQUID_INK         1814            26
# 2996    1      99800  RAINFOREST_RESIN         9996             1
# 2997    1      99900         SQUID_INK         1816            27
# 2998    1      99900  RAINFOREST_RESIN         9998             6
# 2999    1      99900              KELP         2034            27
#
#       bid_price_2  bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  \
# 0             NaN           NaN          NaN           NaN         1838
# ...

# %%
squid_josh[squid_josh['product'] == 'SQUID_INK']['mid_price'].plot()
# Out:
# <Axes: >

# %%
squid['mid_price'].plot()
# Out:
# <Axes: >
