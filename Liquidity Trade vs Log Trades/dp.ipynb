# %%
import pandas as pd
import math
import numpy as np

# Global counter for progress prints.
state_count = 0
STATE_PRINT_INTERVAL = 10000  # Print progress every 10,000 states

# --- Helper Functions with Caching ---

def get_ask_cost_cached(group, q):
    cache = group.setdefault("ask_cache", {})
    if q in cache:
        return cache[q]
    ask_orders = group["ask_orders"]
    remaining = q
    total_cost = 0
    for order in ask_orders:
        if remaining <= 0:
            break
        trade = min(order["volume"], remaining)
        total_cost += trade * order["price"]
        remaining -= trade
    value = total_cost if remaining == 0 else None
    cache[q] = value
    return value

def get_bid_revenue_cached(group, q):
    cache = group.setdefault("bid_cache", {})
    if q in cache:
        return cache[q]
    bid_orders = group["bid_orders"]
    remaining = q
    total_rev = 0
    for order in bid_orders:
        if remaining <= 0:
            break
        trade = min(order["volume"], remaining)
        total_rev += trade * order["price"]
        remaining -= trade
    value = total_rev if remaining == 0 else None
    cache[q] = value
    return value

def group_orders_by_timestamp(df):
    groups = []
    for ts, group_df in df.groupby("timestamp"):
        orders = group_df.to_dict("records")
        ask_orders = sorted([o for o in orders if o["side"].lower() == "ask"],
                             key=lambda x: x["price"])
        bid_orders = sorted([o for o in orders if o["side"].lower() == "bid"],
                             key=lambda x: -x["price"])
        groups.append({
            "timestamp": ts,
            "ask_orders": ask_orders,
            "bid_orders": bid_orders,
            "total_ask": sum(o["volume"] for o in ask_orders),
            "total_bid": sum(o["volume"] for o in bid_orders),
            "ask_cache": {},
            "bid_cache": {}
        })
    groups.sort(key=lambda g: g["timestamp"])
    return groups

# --- Candidate Volumes by Price ---
def candidate_volumes(orders):
    """
    Given a list of orders (assumed sorted either ascending or descending by price),
    returns a sorted list of cumulative volumes aggregated at each distinct price level.
    """
    volumes = []
    cum = 0
    last_price = None
    for order in orders:
        cum += order["volume"]
        if order["price"] != last_price:
            volumes.append(cum)
            last_price = order["price"]
    if cum not in volumes:
        volumes.append(cum)
    return sorted(volumes)

# --- Candidate Set Function (based on aggregated volumes) ---
def candidate_set(cur):
    """
    Returns a list of candidate (x, y) decision pairs for the current group.
    x is the volume to take from the ask side (buy) and y from the bid side (sell).

    The candidate set always includes:
      - The full arbitrage candidate: (min(total_ask, total_bid), min(total_ask, total_bid))
      - Extreme candidates: (total_ask, 0) and (0, total_bid) and (0,0)
      - In addition, for the ask side, it adds candidate x values from the cumulative volumes
        (aggregated by distinct ask prices) and similarly for the bid side.
    """
    avail_buy = cur["total_ask"]
    avail_sell = cur["total_bid"]
    candidates = set()
    # Full arbitrage candidate:
    arb = min(avail_buy, avail_sell)
    candidates.add((arb, arb))
    # Extreme candidates:
    candidates.add((avail_buy, 0))
    candidates.add((0, avail_sell))
    candidates.add((0, 0))
    # Candidate volumes from ask and bid orders:
    Vx = candidate_volumes(cur["ask_orders"])
    Vy = candidate_volumes(cur["bid_orders"])
    for x in Vx:
        for y in Vy:
            if x <= avail_buy and y <= avail_sell:
                candidates.add((x, y))
    # Also add some fraction-based candidates:
    for fraction in [0.25, 0.5, 0.75]:
        x_val = int(round(avail_buy * fraction))
        y_val = int(round(avail_sell * fraction))
        candidates.add((x_val, 0))
        candidates.add((0, y_val))
        candidates.add((x_val, y_val))
    return list(candidates)

# --- Processing a Group's Decision (with Coarse Cost Basis) ---
def process_decision(pos, c, x, y, group):
    """
    Given current state (pos, cost basis c) and a decision (x units buy, y units sell)
    in the given group, returns (profit, new_pos, new_c). New cost basis is rounded to an integer.
    If pos ≠ 0 then c must be provided; otherwise, returns None.
    """
    ask_cost = lambda q: get_ask_cost_cached(group, q)
    bid_rev = lambda q: get_bid_revenue_cached(group, q)
    new_pos = pos + x - y
    profit = 0
    new_c = None

    if pos > 0:
        if c is None:
            return None
        close_qty = min(y, pos)
        if close_qty > 0:
            rev = bid_rev(close_qty)
            if rev is None:
                return None
            profit += rev - close_qty * c
        leftover = pos - close_qty
        extra_sell = max(0, y - pos)
        if leftover + x >= extra_sell:
            new_pos = leftover + x - extra_sell
            total_long = leftover + x
            if x > 0:
                cost_new = ask_cost(x)
                if cost_new is None:
                    return None
            else:
                cost_new = 0
            new_c = ((leftover * c) + cost_new) / total_long if total_long > 0 else None
        else:
            extra = extra_sell - (leftover + x)
            new_pos = -extra
            rev_extra = bid_rev(extra)
            if extra <= 0 or rev_extra is None:
                return None
            new_c = rev_extra / extra
        if new_c is not None:
            new_c = round(new_c)
        return (profit, new_pos, new_c)

    elif pos < 0:
        if c is None:
            return None
        close_qty = min(x, -pos)
        if close_qty > 0:
            cost_new = ask_cost(close_qty)
            if cost_new is None:
                return None
            profit += close_qty * c - cost_new
        leftover = (-pos) - close_qty
        extra_buy = max(0, x - (-pos))
        if leftover + extra_buy >= y:
            new_pos = -(leftover + extra_buy - y)
            total_short = leftover + y
            if y > 0:
                rev_sell = bid_rev(y)
                if rev_sell is None:
                    return None
            else:
                rev_sell = 0
            new_c = ((leftover * c) + rev_sell) / (leftover + y) if (leftover + y) > 0 else None
        else:
            extra = y - (leftover + extra_buy)
            new_pos = extra
            cost_extra = ask_cost(extra)
            if extra <= 0 or cost_extra is None:
                return None
            new_c = cost_extra / extra
        if new_c is not None:
            new_c = round(new_c)
        return (profit, new_pos, new_c)

    else:
        # Starting flat.
        arbitrage_qty = min(x, y)
        if arbitrage_qty > 0:
            cost_arb = ask_cost(arbitrage_qty)
            rev_arb = bid_rev(arbitrage_qty)
            if cost_arb is None or rev_arb is None:
                return None
            profit += rev_arb - cost_arb
        if x > y:
            extra = x - y
            total_cost = ask_cost(x)
            base_cost = ask_cost(arbitrage_qty) if arbitrage_qty > 0 else 0
            if (x > 0 and total_cost is None) or (arbitrage_qty > 0 and base_cost is None):
                return None
            new_c = (total_cost - base_cost) / extra if extra > 0 else None
            new_pos = extra
        elif y > x:
            extra = y - x
            total_rev = bid_rev(y)
            base_rev = bid_rev(arbitrage_qty) if arbitrage_qty > 0 else 0
            if (y > 0 and total_rev is None) or (arbitrage_qty > 0 and base_rev is None):
                return None
            new_c = (total_rev - base_rev) / extra if extra > 0 else None
            new_pos = -extra
        else:
            new_pos = 0
            new_c = None
        if new_c is not None:
            new_c = round(new_c)
        return (profit, new_pos, new_c)

# --- Simulate Individual Trades from a Group ---
def simulate_trades(group, x, y):
    """
    Simulates the individual trades executed for a decision in a given group:
      - Fills x units on the ask side (producing buy trades with positive quantity)
      - Fills y units on the bid side (producing sell trades with negative quantity)
    Returns a list of individual trade records (with 'timestamp', 'price', and 'quantity').
    """
    trades = []
    remaining_buy = x
    for order in group["ask_orders"]:
        if remaining_buy <= 0:
            break
        trade_qty = min(order["volume"], remaining_buy)
        trades.append({
            "timestamp": group["timestamp"],
            "price": order["price"],
            "quantity": trade_qty  # positive for buy
        })
        remaining_buy -= trade_qty
    remaining_sell = y
    for order in group["bid_orders"]:
        if remaining_sell <= 0:
            break
        trade_qty = min(order["volume"], remaining_sell)
        trades.append({
            "timestamp": group["timestamp"],
            "price": order["price"],
            "quantity": -trade_qty  # negative for sell
        })
        remaining_sell -= trade_qty
    return trades

# --- Faster Approximate DP with Enriched Candidate Set ---
def optimize_pnl_for_product(df, max_position):
    """
    Uses an approximate DP which leverages:
      - Coarse cost basis rounding (to an integer)
      - A candidate set that is enriched with cumulative volumes aggregated per price level,
        as well as fixed extreme and fraction-based candidates.
      - It returns the approximate maximum realized profit and a flat list of individual trade records.
    """
    groups = group_orders_by_timestamp(df)
    n_groups = len(groups)
    memo = {}
    decision = {}

    global state_count
    state_count = 0

    def dp(g, pos, c):
        global state_count
        state_count += 1
        if state_count % STATE_PRINT_INTERVAL == 0:
            print(f"Processed {state_count} states; group: {g}, pos: {pos}, cost: {c}")
        if g == n_groups:
            return 0
        key = (g, pos, None if c is None else round(c, 0))
        if key in memo:
            return memo[key]
        cur = groups[g]
        best = -math.inf
        best_decision = (0, 0)
        cand = candidate_set(cur)
        for x, y in cand:
            new_pos = pos + x - y
            if abs(new_pos) > max_position:
                continue
            res = process_decision(pos, c, x, y, cur)
            if res is None:
                continue
            profit_current, new_state_pos, new_state_c = res
            candidate_profit = profit_current + dp(g + 1, new_state_pos, new_state_c)
            if candidate_profit > best:
                best = candidate_profit
                best_decision = (x, y)
        memo[key] = best
        decision[key] = best_decision
        return best

    max_profit = dp(0, 0, None)

    all_trades = []
    def reconstruct(g, pos, c):
        if g == n_groups:
            return
        key = (g, pos, None if c is None else round(c, 0))
        x, y = decision.get(key, (0, 0))
        cur = groups[g]
        # Simulate and record all individual trades for this group.
        if (x, y) != (0, 0):
            trades = simulate_trades(cur, x, y)
            all_trades.extend(trades)
        res = process_decision(pos, c, x, y, cur)
        if res is None:
            new_pos, new_c = pos, c
        else:
            _, new_pos, new_c = res
        reconstruct(g + 1, new_pos, new_c)
    reconstruct(0, 0, None)
    return max_profit, all_trades

# --- Grouping by Product and Running the Approximate DP ---
def optimize_orderbook(csv_file, max_position):
    df = pd.read_csv(csv_file)
    results = {}
    for product, group in df.groupby("product"):
        df_prod = group.sort_values("timestamp").reset_index(drop=True)
        profit, trades = optimize_pnl_for_product(df_prod, max_position)
        results[product] = {"profit": profit, "trades": trades}
    return results


# --- Example Usage ---
if __name__ == '__main__':
    csv_file = 'combined_book_unk_kelp_original.csv'  # adjust as needed
    max_position = 50
    results = optimize_orderbook(csv_file, max_position)
    for product, info in results.items():
        print(f"Product: {product}")
        print("Approximate final realized profit:", info["profit"])
        print("Individual trade records:")
        for trade in info["trades"]:
            print(trade)
        print("-" * 40)
# Out:
# Processed 10000 states; group: 997, pos: -2, cost: 2036
# Processed 20000 states; group: 993, pos: -16, cost: None
# Processed 30000 states; group: 1000, pos: -12, cost: 2034
# Processed 40000 states; group: 995, pos: 30, cost: 2038
# Processed 50000 states; group: 985, pos: 12, cost: 2037
# Processed 60000 states; group: 981, pos: 15, cost: 2037
# Processed 70000 states; group: 979, pos: -13, cost: 2035
# Processed 80000 states; group: 988, pos: 6, cost: 2038
# Processed 90000 states; group: 978, pos: 41, cost: 2037
# Processed 100000 states; group: 990, pos: 33, cost: 2037
# Processed 110000 states; group: 972, pos: 27, cost: 2038
# Processed 120000 states; group: 968, pos: -20, cost: 2034
# Processed 130000 states; group: 968, pos: 5, cost: 2036
# Processed 140000 states; group: 965, pos: 32, cost: 2036
# Processed 150000 states; group: 990, pos: -9, cost: 2036
# Processed 160000 states; group: 961, pos: 35, cost: 2038
# Processed 170000 states; group: 958, pos: 49, cost: 2037
# Processed 180000 states; group: 957, pos: 50, cost: 2037
# Processed 190000 states; group: 959, pos: 25, cost: 2037
# Processed 200000 states; group: 956, pos: -16, cost: 2034
# Processed 210000 states; group: 949, pos: -7, cost: 2034
# Processed 220000 states; group: 984, pos: -11, cost: 2035
# Processed 230000 states; group: 944, pos: 23, cost: 2038
# Processed 240000 states; group: 951, pos: -9, cost: 2034
# Processed 250000 states; group: 941, pos: 15, cost: 2038
# Processed 260000 states; group: 975, pos: 22, cost: 2038
# Processed 270000 states; group: 945, pos: 43, cost: 2036
# Processed 280000 states; group: 934, pos: 28, cost: 2038
# Processed 290000 states; group: 931, pos: 24, cost: 2038
# Processed 300000 states; group: 932, pos: 49, cost: 2037
# Processed 310000 states; group: 937, pos: -4, cost: 2037
# Processed 320000 states; group: 922, pos: -13, cost: 2034
# Processed 330000 states; group: 920, pos: 6, cost: 2038
# Processed 340000 states; group: 925, pos: 23, cost: 2037
# Processed 350000 states; group: 914, pos: 19, cost: 2036
# Processed 360000 states; group: 915, pos: 18, cost: 2038
# Processed 370000 states; group: 914, pos: -22, cost: None
# Processed 380000 states; group: 908, pos: 11, cost: 2038
# Processed 390000 states; group: 964, pos: 0, cost: None
# Processed 400000 states; group: 955, pos: 24, cost: 2035
# Processed 410000 states; group: 939, pos: 42, cost: 2036
# Processed 420000 states; group: 909, pos: 35, cost: 2037
# Processed 430000 states; group: 923, pos: -5, cost: 2036
# Processed 440000 states; group: 906, pos: 28, cost: 2038
# Processed 450000 states; group: 902, pos: 13, cost: 2036
# Processed 460000 states; group: 900, pos: 3, cost: 2037
# Processed 470000 states; group: 908, pos: 27, cost: 2035
# Processed 480000 states; group: 897, pos: 35, cost: 2037
# Processed 490000 states; group: 894, pos: -8, cost: None
# Processed 500000 states; group: 889, pos: 3, cost: 2038
# Processed 510000 states; group: 889, pos: 44, cost: 2037
# Processed 520000 states; group: 970, pos: -17, cost: 2035
# Processed 530000 states; group: 890, pos: -23, cost: 2035
# Processed 540000 states; group: 899, pos: 23, cost: 2038
# Processed 550000 states; group: 884, pos: 1, cost: 2037
# Processed 560000 states; group: 878, pos: 8, cost: 2038
# Processed 570000 states; group: 878, pos: 22, cost: 2038
# Processed 580000 states; group: 872, pos: -15, cost: None
# Processed 590000 states; group: 867, pos: -36, cost: None
# Processed 600000 states; group: 862, pos: 3, cost: 2038
# Processed 610000 states; group: 861, pos: 34, cost: 2038
# Processed 620000 states; group: 861, pos: 16, cost: 2038
# Processed 630000 states; group: 878, pos: 24, cost: 2036
# Processed 640000 states; group: 855, pos: -19, cost: 2034
# Processed 650000 states; group: 851, pos: 4, cost: 2036
# Processed 660000 states; group: 850, pos: -1, cost: 2035
# Processed 670000 states; group: 842, pos: -4, cost: 2035
# Processed 680000 states; group: 863, pos: 27, cost: 2038
# Processed 690000 states; group: 843, pos: -4, cost: None
# Processed 700000 states; group: 876, pos: -7, cost: 2036
# Processed 710000 states; group: 860, pos: -20, cost: 2036
# Processed 720000 states; group: 848, pos: -6, cost: 2036
# Processed 730000 states; group: 910, pos: -23, cost: 2036
# Processed 740000 states; group: 836, pos: -14, cost: None
# Processed 750000 states; group: 834, pos: 5, cost: 2037
# Processed 760000 states; group: 849, pos: 27, cost: 2036
# Processed 770000 states; group: 829, pos: 45, cost: 2037
# Processed 780000 states; group: 831, pos: -24, cost: None
# Processed 790000 states; group: 822, pos: 8, cost: 2038
# Processed 800000 states; group: 819, pos: -8, cost: 2035
# Processed 810000 states; group: 832, pos: -3, cost: 2036
# Processed 820000 states; group: 814, pos: 34, cost: 2038
# Processed 830000 states; group: 815, pos: 17, cost: 2038
# Processed 840000 states; group: 813, pos: 47, cost: 2038
# Processed 850000 states; group: 809, pos: 24, cost: 2037
# Processed 860000 states; group: 808, pos: -4, cost: 2036
# Processed 870000 states; group: 808, pos: 9, cost: 2038
# Processed 880000 states; group: 801, pos: 16, cost: 2038
# Processed 890000 states; group: 883, pos: -11, cost: 2036
# Processed 900000 states; group: 800, pos: -17, cost: None
# Processed 910000 states; group: 802, pos: 7, cost: 2038
# Processed 920000 states; group: 797, pos: -8, cost: 2035
# Processed 930000 states; group: 795, pos: 2, cost: 2038
# Processed 940000 states; group: 797, pos: -2, cost: 2035
# Processed 950000 states; group: 786, pos: 37, cost: 2038
# Processed 960000 states; group: 782, pos: 50, cost: 2038
# Processed 970000 states; group: 789, pos: 45, cost: 2037
# Processed 980000 states; group: 787, pos: -17, cost: 2034
# Processed 990000 states; group: 859, pos: 6, cost: 2036
# Processed 1000000 states; group: 806, pos: 29, cost: 2037
# Processed 1010000 states; group: 777, pos: 33, cost: 2038
# Processed 1020000 states; group: 780, pos: -25, cost: 2036
# Processed 1030000 states; group: 772, pos: 33, cost: 2037
# Processed 1040000 states; group: 842, pos: -37, cost: 2034
# Processed 1050000 states; group: 770, pos: -2, cost: None
# Processed 1060000 states; group: 765, pos: -1, cost: 2034
# Processed 1070000 states; group: 768, pos: 5, cost: 2037
# Processed 1080000 states; group: 765, pos: 36, cost: 2038
# Processed 1090000 states; group: 759, pos: 27, cost: 2038
# Processed 1100000 states; group: 755, pos: 8, cost: 2037
# Processed 1110000 states; group: 754, pos: -11, cost: 2035
# Processed 1120000 states; group: 753, pos: -25, cost: None
# Processed 1130000 states; group: 990, pos: -1, cost: 2033
# Processed 1140000 states; group: 949, pos: -5, cost: 2033
# Processed 1150000 states; group: 818, pos: -8, cost: None
# Processed 1160000 states; group: 934, pos: 15, cost: 2036
# Processed 1170000 states; group: 799, pos: 11, cost: 2038
# Processed 1180000 states; group: 777, pos: -4, cost: None
# Processed 1190000 states; group: 977, pos: -3, cost: None
# Processed 1200000 states; group: 886, pos: 0, cost: 2034
# Processed 1210000 states; group: 894, pos: -9, cost: 2034
# Processed 1220000 states; group: 860, pos: 7, cost: 2035
# Processed 1230000 states; group: 851, pos: -4, cost: 2034
# Processed 1240000 states; group: 842, pos: 3, cost: 2035
# Processed 1250000 states; group: 821, pos: 37, cost: 2035
# Processed 1260000 states; group: 797, pos: -18, cost: 2035
# Processed 1270000 states; group: 803, pos: 3, cost: 2035
# Processed 1280000 states; group: 781, pos: 32, cost: 2036
# Processed 1290000 states; group: 889, pos: 24, cost: 2038
# Processed 1300000 states; group: 749, pos: -18, cost: 2036
# Processed 1310000 states; group: 896, pos: -12, cost: 2033
# Processed 1320000 states; group: 750, pos: 44, cost: 2036
# Processed 1330000 states; group: 782, pos: -12, cost: 2036
# Processed 1340000 states; group: 745, pos: -21, cost: 2035
# Processed 1350000 states; group: 745, pos: -10, cost: 2034
# Processed 1360000 states; group: 742, pos: 42, cost: 2036
# Processed 1370000 states; group: 855, pos: -10, cost: 2034
# Processed 1380000 states; group: 733, pos: 5, cost: 2036
# Processed 1390000 states; group: 842, pos: 4, cost: 2034
# Processed 1400000 states; group: 852, pos: -36, cost: 2033
# Processed 1410000 states; group: 731, pos: -7, cost: 2033
# Processed 1420000 states; group: 808, pos: 20, cost: 2036
# Processed 1430000 states; group: 985, pos: 24, cost: 2034
# Processed 1440000 states; group: 980, pos: 21, cost: 2034
# Processed 1450000 states; group: 967, pos: 37, cost: 2035
# Processed 1460000 states; group: 938, pos: 25, cost: 2038
# Processed 1470000 states; group: 905, pos: 22, cost: 2035
# Processed 1480000 states; group: 904, pos: 24, cost: 2038
# Processed 1490000 states; group: 757, pos: -6, cost: 2034
# Processed 1500000 states; group: 876, pos: 30, cost: 2035
# Processed 1510000 states; group: 858, pos: 43, cost: 2036
# Processed 1520000 states; group: 870, pos: 34, cost: 2037
# Processed 1530000 states; group: 851, pos: 25, cost: 2034
# Processed 1540000 states; group: 768, pos: 18, cost: 2035
# Processed 1550000 states; group: 800, pos: 42, cost: 2037
# Processed 1560000 states; group: 746, pos: 43, cost: 2035
# Processed 1570000 states; group: 730, pos: 14, cost: 2037
# Processed 1580000 states; group: 736, pos: -3, cost: None
# Processed 1590000 states; group: 721, pos: 32, cost: 2037
# Processed 1600000 states; group: 720, pos: 17, cost: 2037
# Processed 1610000 states; group: 746, pos: -19, cost: 2033
# Processed 1620000 states; group: 746, pos: -20, cost: 2033
# Processed 1630000 states; group: 738, pos: -35, cost: 2034
# Processed 1640000 states; group: 726, pos: 8, cost: 2037
# Processed 1650000 states; group: 722, pos: -23, cost: 2036
# Processed 1660000 states; group: 718, pos: -13, cost: 2035
# Processed 1670000 states; group: 706, pos: -3, cost: 2034
# Processed 1680000 states; group: 700, pos: -2, cost: None
# Processed 1690000 states; group: 701, pos: 4, cost: 2037
# Processed 1700000 states; group: 710, pos: 14, cost: 2036
# Processed 1710000 states; group: 696, pos: 24, cost: 2037
# Processed 1720000 states; group: 690, pos: 46, cost: 2037
# Processed 1730000 states; group: 689, pos: 28, cost: 2036
# Processed 1740000 states; group: 689, pos: 50, cost: 2036
# Processed 1750000 states; group: 687, pos: 9, cost: 2037
# Processed 1760000 states; group: 689, pos: -7, cost: None
# Processed 1770000 states; group: 744, pos: -32, cost: 2033
# Processed 1780000 states; group: 686, pos: -3, cost: 2034
# Processed 1790000 states; group: 682, pos: -15, cost: 2035
# Processed 1800000 states; group: 688, pos: -8, cost: 2034
# Processed 1810000 states; group: 674, pos: 6, cost: 2037
# Processed 1820000 states; group: 671, pos: 5, cost: 2037
# Processed 1830000 states; group: 676, pos: -23, cost: 2034
# Processed 1840000 states; group: 664, pos: 12, cost: 2037
# Processed 1850000 states; group: 661, pos: 13, cost: 2037
# Processed 1860000 states; group: 655, pos: 48, cost: 2037
# Processed 1870000 states; group: 658, pos: -16, cost: 2035
# Processed 1880000 states; group: 678, pos: 34, cost: 2035
# Processed 1890000 states; group: 658, pos: 15, cost: 2037
# Processed 1900000 states; group: 650, pos: 11, cost: 2037
# Processed 1910000 states; group: 651, pos: 18, cost: 2036
# Processed 1920000 states; group: 644, pos: -13, cost: 2034
# Processed 1930000 states; group: 647, pos: 28, cost: 2037
# Processed 1940000 states; group: 708, pos: 47, cost: 2037
# Processed 1950000 states; group: 639, pos: 43, cost: 2037
# Processed 1960000 states; group: 646, pos: 14, cost: 2037
# Processed 1970000 states; group: 638, pos: 19, cost: 2035
# Processed 1980000 states; group: 661, pos: -21, cost: 2033
# Processed 1990000 states; group: 628, pos: 27, cost: 2037
# Processed 2000000 states; group: 631, pos: 8, cost: 2037
# Processed 2010000 states; group: 630, pos: 17, cost: 2036
# Processed 2020000 states; group: 637, pos: 5, cost: 2037
# Processed 2030000 states; group: 710, pos: 6, cost: 2037
# Processed 2040000 states; group: 707, pos: 49, cost: 2035
# Processed 2050000 states; group: 685, pos: 9, cost: 2037
# Processed 2060000 states; group: 686, pos: 32, cost: 2034
# Processed 2070000 states; group: 619, pos: 7, cost: 2037
# Processed 2080000 states; group: 621, pos: 3, cost: 2037
# Processed 2090000 states; group: 617, pos: -13, cost: 2035
# Processed 2100000 states; group: 993, pos: -35, cost: 2033
# Processed 2110000 states; group: 614, pos: 1, cost: 2037
# Processed 2120000 states; group: 687, pos: 17, cost: 2037
# Processed 2130000 states; group: 650, pos: 24, cost: 2037
# Processed 2140000 states; group: 855, pos: -13, cost: 2033
# Processed 2150000 states; group: 797, pos: -33, cost: 2036
# Processed 2160000 states; group: 702, pos: 30, cost: 2037
# Processed 2170000 states; group: 761, pos: -41, cost: 2036
# Processed 2180000 states; group: 667, pos: 27, cost: 2037
# Processed 2190000 states; group: 658, pos: 17, cost: 2034
# Processed 2200000 states; group: 617, pos: 44, cost: 2036
# Processed 2210000 states; group: 607, pos: 22, cost: 2037
# Processed 2220000 states; group: 604, pos: 9, cost: 2037
# Processed 2230000 states; group: 599, pos: -13, cost: 2034
# Processed 2240000 states; group: 617, pos: 45, cost: 2036
# Processed 2250000 states; group: 597, pos: 0, cost: None
# Processed 2260000 states; group: 620, pos: -1, cost: None
# Processed 2270000 states; group: 593, pos: 31, cost: 2037
# Processed 2280000 states; group: 592, pos: 45, cost: 2037
# Processed 2290000 states; group: 600, pos: -29, cost: 2035
# Processed 2300000 states; group: 593, pos: 10, cost: 2037
# Processed 2310000 states; group: 590, pos: 14, cost: 2036
# Processed 2320000 states; group: 589, pos: 1, cost: 2035
# Processed 2330000 states; group: 586, pos: 26, cost: 2037
# Processed 2340000 states; group: 582, pos: 5, cost: 2037
# Processed 2350000 states; group: 636, pos: 28, cost: 2034
# Processed 2360000 states; group: 608, pos: 32, cost: 2036
# Processed 2370000 states; group: 589, pos: -8, cost: 2034
# Processed 2380000 states; group: 578, pos: 31, cost: 2037
# Processed 2390000 states; group: 579, pos: 24, cost: 2037
# Processed 2400000 states; group: 572, pos: 28, cost: 2037
# Processed 2410000 states; group: 569, pos: 6, cost: 2037
# Processed 2420000 states; group: 578, pos: -18, cost: 2034
# Processed 2430000 states; group: 583, pos: -32, cost: 2033
# Processed 2440000 states; group: 565, pos: 3, cost: 2037
# Processed 2450000 states; group: 592, pos: -21, cost: 2033
# Processed 2460000 states; group: 564, pos: -16, cost: 2035
# Processed 2470000 states; group: 560, pos: 23, cost: 2036
# Processed 2480000 states; group: 553, pos: 41, cost: 2037
# Processed 2490000 states; group: 577, pos: -16, cost: 2036
# Processed 2500000 states; group: 589, pos: -10, cost: 2035
# Processed 2510000 states; group: 543, pos: 0, cost: None
# Processed 2520000 states; group: 542, pos: 29, cost: 2037
# Processed 2530000 states; group: 544, pos: 14, cost: 2036
# Processed 2540000 states; group: 537, pos: 11, cost: 2037
# Processed 2550000 states; group: 550, pos: -30, cost: 2034
# Processed 2560000 states; group: 571, pos: -28, cost: 2036
# Processed 2570000 states; group: 535, pos: -31, cost: 2036
# Processed 2580000 states; group: 530, pos: -16, cost: 2033
# Processed 2590000 states; group: 547, pos: 5, cost: 2035
# Processed 2600000 states; group: 526, pos: 26, cost: 2036
# Processed 2610000 states; group: 524, pos: 41, cost: 2036
# Processed 2620000 states; group: 532, pos: -23, cost: 2034
# Processed 2630000 states; group: 524, pos: -14, cost: None
# Processed 2640000 states; group: 530, pos: 0, cost: 2034
# Processed 2650000 states; group: 536, pos: -8, cost: 2035
# Processed 2660000 states; group: 529, pos: 12, cost: 2037
# Processed 2670000 states; group: 521, pos: 41, cost: 2035
# Processed 2680000 states; group: 509, pos: 6, cost: 2037
# Processed 2690000 states; group: 504, pos: 5, cost: 2036
# Processed 2700000 states; group: 500, pos: -9, cost: 2034
# Processed 2710000 states; group: 521, pos: 18, cost: 2036
# Processed 2720000 states; group: 499, pos: 10, cost: 2037
# Processed 2730000 states; group: 498, pos: -17, cost: 2035
# Processed 2740000 states; group: 493, pos: -2, cost: None
# Processed 2750000 states; group: 514, pos: -29, cost: 2034
# Processed 2760000 states; group: 495, pos: 30, cost: 2036
# Processed 2770000 states; group: 565, pos: 20, cost: 2036
# Processed 2780000 states; group: 576, pos: 33, cost: 2034
# Processed 2790000 states; group: 558, pos: 34, cost: 2037
# Processed 2800000 states; group: 540, pos: 35, cost: 2034
# Processed 2810000 states; group: 489, pos: 13, cost: 2036
# Processed 2820000 states; group: 514, pos: 22, cost: 2034
# Processed 2830000 states; group: 485, pos: -1, cost: 2033
# Processed 2840000 states; group: 494, pos: 21, cost: 2037
# Processed 2850000 states; group: 481, pos: -17, cost: 2033
# Processed 2860000 states; group: 481, pos: 16, cost: 2037
# Processed 2870000 states; group: 476, pos: -14, cost: 2034
# Processed 2880000 states; group: 484, pos: -39, cost: 2033
# Processed 2890000 states; group: 474, pos: 13, cost: 2036
# Processed 2900000 states; group: 472, pos: -7, cost: 2035
# Processed 2910000 states; group: 462, pos: 41, cost: 2037
# Processed 2920000 states; group: 465, pos: 10, cost: 2037
# Processed 2930000 states; group: 471, pos: -6, cost: 2033
# Processed 2940000 states; group: 465, pos: 29, cost: 2035
# Processed 2950000 states; group: 456, pos: -21, cost: 2034
# Processed 2960000 states; group: 451, pos: 27, cost: 2037
# Processed 2970000 states; group: 445, pos: -2, cost: 2034
# Processed 2980000 states; group: 445, pos: -2, cost: 2035
# Processed 2990000 states; group: 528, pos: -13, cost: 2033
# Processed 3000000 states; group: 749, pos: 35, cost: 2037
# Processed 3010000 states; group: 730, pos: 11, cost: 2037
# Processed 3020000 states; group: 712, pos: 48, cost: 2038
# Processed 3030000 states; group: 693, pos: 46, cost: 2038
# Processed 3040000 states; group: 675, pos: 18, cost: 2037
# Processed 3050000 states; group: 659, pos: -2, cost: 2034
# Processed 3060000 states; group: 643, pos: 22, cost: 2037
# Processed 3070000 states; group: 624, pos: 24, cost: 2037
# Processed 3080000 states; group: 607, pos: 40, cost: 2038
# Processed 3090000 states; group: 590, pos: 5, cost: 2037
# Processed 3100000 states; group: 574, pos: 9, cost: 2037
# Processed 3110000 states; group: 558, pos: 31, cost: 2038
# Processed 3120000 states; group: 540, pos: 30, cost: 2038
# Processed 3130000 states; group: 524, pos: 34, cost: 2038
# Processed 3140000 states; group: 508, pos: 8, cost: 2038
# Processed 3150000 states; group: 493, pos: 25, cost: 2037
# Processed 3160000 states; group: 469, pos: 11, cost: 2036
# Processed 3170000 states; group: 458, pos: 50, cost: 2038
# Processed 3180000 states; group: 494, pos: 25, cost: 2037
# Processed 3190000 states; group: 449, pos: 8, cost: 2036
# Processed 3200000 states; group: 456, pos: -19, cost: 2035
# Processed 3210000 states; group: 591, pos: -22, cost: None
# Processed 3220000 states; group: 661, pos: 17, cost: 2037
# Processed 3230000 states; group: 618, pos: 7, cost: 2037
# Processed 3240000 states; group: 494, pos: 17, cost: 2037
# Processed 3250000 states; group: 744, pos: 6, cost: 2035
# Processed 3260000 states; group: 618, pos: -26, cost: None
# Processed 3270000 states; group: 701, pos: 5, cost: 2037
# Processed 3280000 states; group: 544, pos: 13, cost: 2037
# Processed 3290000 states; group: 698, pos: 7, cost: 2037
# Processed 3300000 states; group: 441, pos: 11, cost: 2037
# Processed 3310000 states; group: 439, pos: 26, cost: 2038
# Processed 3320000 states; group: 438, pos: -6, cost: 2035
# Processed 3330000 states; group: 444, pos: 42, cost: 2037
# Processed 3340000 states; group: 438, pos: 11, cost: 2038
# Processed 3350000 states; group: 426, pos: 21, cost: 2038
# Processed 3360000 states; group: 424, pos: 14, cost: 2037
# Processed 3370000 states; group: 436, pos: -9, cost: 2034
# Processed 3380000 states; group: 433, pos: 14, cost: 2038
# Processed 3390000 states; group: 421, pos: 10, cost: 2036
# Processed 3400000 states; group: 446, pos: -2, cost: 2033
# Processed 3410000 states; group: 421, pos: -3, cost: 2033
# Processed 3420000 states; group: 409, pos: 9, cost: 2037
# Processed 3430000 states; group: 432, pos: -20, cost: 2035
# Processed 3440000 states; group: 405, pos: -11, cost: 2034
# Processed 3450000 states; group: 456, pos: 4, cost: 2035
# Processed 3460000 states; group: 446, pos: 34, cost: 2035
# Processed 3470000 states; group: 427, pos: 44, cost: 2036
# Processed 3480000 states; group: 440, pos: 29, cost: 2037
# Processed 3490000 states; group: 413, pos: 38, cost: 2038
# Processed 3500000 states; group: 399, pos: 7, cost: 2037
# Processed 3510000 states; group: 395, pos: 17, cost: 2038
# Processed 3520000 states; group: 406, pos: 25, cost: 2037
# Processed 3530000 states; group: 392, pos: -2, cost: 2035
# Processed 3540000 states; group: 387, pos: 28, cost: 2037
# Processed 3550000 states; group: 384, pos: 27, cost: 2036
# Processed 3560000 states; group: 437, pos: -25, cost: 2036
# Processed 3570000 states; group: 473, pos: -4, cost: 2036
# Processed 3580000 states; group: 379, pos: 13, cost: 2035
# Processed 3590000 states; group: 388, pos: -3, cost: 2035
# Processed 3600000 states; group: 526, pos: -32, cost: 2035
# Processed 3610000 states; group: 513, pos: 15, cost: 2037
# Processed 3620000 states; group: 374, pos: 46, cost: 2036
# Processed 3630000 states; group: 369, pos: -21, cost: 2034
# Processed 3640000 states; group: 367, pos: -10, cost: 2034
# Processed 3650000 states; group: 360, pos: -10, cost: None
# Processed 3660000 states; group: 386, pos: -5, cost: None
# Processed 3670000 states; group: 394, pos: 18, cost: 2038
# Processed 3680000 states; group: 377, pos: 4, cost: 2036
# Processed 3690000 states; group: 359, pos: 39, cost: 2037
# Processed 3700000 states; group: 354, pos: 13, cost: 2037
# Processed 3710000 states; group: 351, pos: -33, cost: None
# Processed 3720000 states; group: 382, pos: 5, cost: 2036
# Processed 3730000 states; group: 388, pos: -8, cost: None
# Processed 3740000 states; group: 416, pos: -6, cost: 2033
# Processed 3750000 states; group: 426, pos: -12, cost: 2033
# Processed 3760000 states; group: 462, pos: 6, cost: 2037
# Processed 3770000 states; group: 344, pos: -33, cost: None
# Processed 3780000 states; group: 351, pos: 44, cost: 2037
# Processed 3790000 states; group: 340, pos: -13, cost: 2034
# Processed 3800000 states; group: 338, pos: 42, cost: 2036
# Processed 3810000 states; group: 376, pos: 19, cost: 2035
# Processed 3820000 states; group: 360, pos: 16, cost: 2035
# Processed 3830000 states; group: 334, pos: 2, cost: 2037
# Processed 3840000 states; group: 330, pos: 11, cost: 2037
# Processed 3850000 states; group: 327, pos: 43, cost: 2037
# Processed 3860000 states; group: 328, pos: 50, cost: 2036
# Processed 3870000 states; group: 322, pos: 18, cost: 2037
# Processed 3880000 states; group: 317, pos: -4, cost: 2035
# Processed 3890000 states; group: 331, pos: -25, cost: 2034
# Processed 3900000 states; group: 324, pos: 8, cost: 2035
# Processed 3910000 states; group: 477, pos: 46, cost: 2035
# Processed 3920000 states; group: 426, pos: 28, cost: 2037
# Processed 3930000 states; group: 429, pos: 35, cost: 2035
# Processed 3940000 states; group: 444, pos: 43, cost: 2035
# Processed 3950000 states; group: 414, pos: 35, cost: 2036
# Processed 3960000 states; group: 388, pos: 44, cost: 2036
# Processed 3970000 states; group: 385, pos: 0, cost: None
# Processed 3980000 states; group: 371, pos: 38, cost: 2034
# Processed 3990000 states; group: 354, pos: 16, cost: 2037
# Processed 4000000 states; group: 330, pos: 39, cost: 2035
# Processed 4010000 states; group: 316, pos: -5, cost: 2034
# Processed 4020000 states; group: 311, pos: 27, cost: 2037
# Processed 4030000 states; group: 310, pos: 9, cost: 2035
# Processed 4040000 states; group: 304, pos: 21, cost: 2037
# Processed 4050000 states; group: 301, pos: 26, cost: 2036
# Processed 4060000 states; group: 351, pos: 14, cost: 2037
# Processed 4070000 states; group: 308, pos: 33, cost: 2035
# Processed 4080000 states; group: 300, pos: 32, cost: 2036
# Processed 4090000 states; group: 298, pos: -17, cost: 2034
# Processed 4100000 states; group: 288, pos: 50, cost: 2036
# Processed 4110000 states; group: 298, pos: 38, cost: 2034
# Processed 4120000 states; group: 282, pos: -6, cost: 2033
# Processed 4130000 states; group: 294, pos: -10, cost: 2035
# Processed 4140000 states; group: 274, pos: 50, cost: 2036
# Processed 4150000 states; group: 277, pos: 9, cost: 2036
# Processed 4160000 states; group: 292, pos: -38, cost: 2033
# Processed 4170000 states; group: 270, pos: 3, cost: 2036
# Processed 4180000 states; group: 269, pos: 0, cost: None
# Processed 4190000 states; group: 279, pos: 32, cost: 2034
# Processed 4200000 states; group: 264, pos: -20, cost: 2033
# Processed 4210000 states; group: 297, pos: -7, cost: 2035
# Processed 4220000 states; group: 260, pos: 7, cost: 2036
# Processed 4230000 states; group: 255, pos: 4, cost: 2035
# Processed 4240000 states; group: 252, pos: 8, cost: 2036
# Processed 4250000 states; group: 248, pos: -1, cost: 2033
# Processed 4260000 states; group: 512, pos: 10, cost: 2037
# Processed 4270000 states; group: 336, pos: -1, cost: 2033
# Processed 4280000 states; group: 244, pos: -7, cost: None
# Processed 4290000 states; group: 241, pos: 5, cost: 2036
# Processed 4300000 states; group: 237, pos: -7, cost: 2033
# Processed 4310000 states; group: 241, pos: -15, cost: 2033
# Processed 4320000 states; group: 237, pos: 17, cost: 2036
# Processed 4330000 states; group: 240, pos: -23, cost: 2034
# Processed 4340000 states; group: 234, pos: 11, cost: 2035
# Processed 4350000 states; group: 228, pos: 10, cost: 2036
# Processed 4360000 states; group: 990, pos: 6, cost: 2038
# Processed 4370000 states; group: 638, pos: -44, cost: None
# Processed 4380000 states; group: 231, pos: -24, cost: 2035
# Processed 4390000 states; group: 825, pos: 7, cost: 2038
# Processed 4400000 states; group: 883, pos: 1, cost: 2037
# Processed 4410000 states; group: 516, pos: -2, cost: 2034
# Processed 4420000 states; group: 748, pos: 6, cost: 2037
# Processed 4430000 states; group: 402, pos: 6, cost: 2036
# Processed 4440000 states; group: 437, pos: 17, cost: 2038
# Processed 4450000 states; group: 518, pos: 10, cost: 2037
# Processed 4460000 states; group: 565, pos: 13, cost: 2037
# Processed 4470000 states; group: 453, pos: -5, cost: 2032
# Processed 4480000 states; group: 963, pos: 10, cost: 2038
# Processed 4490000 states; group: 361, pos: -16, cost: 2032
# Processed 4500000 states; group: 687, pos: 20, cost: 2037
# Processed 4510000 states; group: 498, pos: -8, cost: 2033
# Processed 4520000 states; group: 860, pos: 3, cost: 2038
# Processed 4530000 states; group: 430, pos: 15, cost: 2038
# Processed 4540000 states; group: 607, pos: -7, cost: 2032
# Processed 4550000 states; group: 993, pos: -5, cost: 2033
# Processed 4560000 states; group: 439, pos: -4, cost: 2034
# Processed 4570000 states; group: 912, pos: -20, cost: 2032
# Processed 4580000 states; group: 240, pos: -7, cost: 2032
# Processed 4590000 states; group: 439, pos: -6, cost: 2033
# Processed 4600000 states; group: 977, pos: -7, cost: 2032
# Processed 4610000 states; group: 228, pos: -5, cost: None
# Processed 4620000 states; group: 381, pos: -14, cost: 2032
# Processed 4630000 states; group: 850, pos: -27, cost: 2032
# Processed 4640000 states; group: 651, pos: -14, cost: 2032
# Processed 4650000 states; group: 412, pos: -9, cost: 2032
# Processed 4660000 states; group: 319, pos: 0, cost: 2033
# Processed 4670000 states; group: 356, pos: 29, cost: 2037
# Processed 4680000 states; group: 224, pos: 17, cost: 2036
# Processed 4690000 states; group: 223, pos: 0, cost: 2032
# Processed 4700000 states; group: 695, pos: -31, cost: 2032
# Processed 4710000 states; group: 228, pos: 33, cost: 2035
# Processed 4720000 states; group: 657, pos: 14, cost: 2037
# Processed 4730000 states; group: 768, pos: 33, cost: 2037
# Processed 4740000 states; group: 900, pos: 2, cost: 2038
# Processed 4750000 states; group: 988, pos: -21, cost: 2034
# Processed 4760000 states; group: 403, pos: -23, cost: 2035
# Processed 4770000 states; group: 548, pos: 17, cost: 2035
# Processed 4780000 states; group: 708, pos: 14, cost: 2036
# Processed 4790000 states; group: 635, pos: 3, cost: 2033
# Processed 4800000 states; group: 714, pos: 45, cost: 2036
# Processed 4810000 states; group: 743, pos: 47, cost: 2035
# Processed 4820000 states; group: 896, pos: -16, cost: 2034
# Processed 4830000 states; group: 950, pos: 10, cost: 2033
# Processed 4840000 states; group: 850, pos: 15, cost: 2033
# Processed 4850000 states; group: 767, pos: 23, cost: 2033
# Processed 4860000 states; group: 836, pos: 22, cost: 2033
# Processed 4870000 states; group: 918, pos: 33, cost: 2037
# Processed 4880000 states; group: 952, pos: 40, cost: 2033
# Processed 4890000 states; group: 773, pos: 22, cost: 2035
# Processed 4900000 states; group: 649, pos: 6, cost: 2033
# Processed 4910000 states; group: 883, pos: 45, cost: 2035
# Processed 4920000 states; group: 852, pos: 45, cost: 2033
# Processed 4930000 states; group: 760, pos: 46, cost: 2033
# Processed 4940000 states; group: 661, pos: 14, cost: 2033
# Processed 4950000 states; group: 644, pos: -9, cost: 2033
# Processed 4960000 states; group: 693, pos: 39, cost: 2034
# Processed 4970000 states; group: 638, pos: 34, cost: 2034
# Processed 4980000 states; group: 680, pos: 50, cost: 2034
# Processed 4990000 states; group: 645, pos: -1, cost: 2034
# Processed 5000000 states; group: 577, pos: 5, cost: 2037
# Processed 5010000 states; group: 610, pos: 36, cost: 2035
# Processed 5020000 states; group: 425, pos: 4, cost: 2038
# Processed 5030000 states; group: 584, pos: 28, cost: 2037
# Processed 5040000 states; group: 300, pos: -30, cost: 2034
# Processed 5050000 states; group: 514, pos: -2, cost: 2034
# Processed 5060000 states; group: 576, pos: 26, cost: 2033
# Processed 5070000 states; group: 533, pos: 26, cost: 2033
# Processed 5080000 states; group: 497, pos: 26, cost: 2033
# Processed 5090000 states; group: 445, pos: 33, cost: 2035
# Processed 5100000 states; group: 477, pos: 36, cost: 2035
# Processed 5110000 states; group: 397, pos: -7, cost: 2034
# Processed 5120000 states; group: 470, pos: 42, cost: 2033
# Processed 5130000 states; group: 445, pos: 31, cost: 2036
# Processed 5140000 states; group: 353, pos: 29, cost: 2034
# Processed 5150000 states; group: 393, pos: 48, cost: 2033
# Processed 5160000 states; group: 380, pos: 48, cost: 2036
# Processed 5170000 states; group: 330, pos: 46, cost: 2035
# Processed 5180000 states; group: 291, pos: 33, cost: 2035
# Processed 5190000 states; group: 265, pos: 27, cost: 2035
# Processed 5200000 states; group: 256, pos: 15, cost: 2033
# Processed 5210000 states; group: 246, pos: 45, cost: 2033
# Processed 5220000 states; group: 220, pos: 9, cost: 2034
# Processed 5230000 states; group: 241, pos: -13, cost: 2035
# Processed 5240000 states; group: 232, pos: -43, cost: 2035
# Processed 5250000 states; group: 213, pos: 44, cost: 2036
# Processed 5260000 states; group: 209, pos: 10, cost: 2036
# Processed 5270000 states; group: 210, pos: 25, cost: 2036
# Processed 5280000 states; group: 200, pos: 32, cost: 2036
# Processed 5290000 states; group: 231, pos: 24, cost: 2036
# Processed 5300000 states; group: 210, pos: 16, cost: 2034
# Processed 5310000 states; group: 197, pos: 3, cost: 2036
# Processed 5320000 states; group: 192, pos: -18, cost: 2034
# Processed 5330000 states; group: 193, pos: 20, cost: 2036
# Processed 5340000 states; group: 194, pos: -12, cost: 2033
# Processed 5350000 states; group: 183, pos: 37, cost: 2036
# Processed 5360000 states; group: 195, pos: 29, cost: 2035
# Processed 5370000 states; group: 187, pos: -1, cost: 2034
# Processed 5380000 states; group: 179, pos: 32, cost: 2035
# Processed 5390000 states; group: 201, pos: -33, cost: None
# Processed 5400000 states; group: 182, pos: -9, cost: None
# Processed 5410000 states; group: 172, pos: -22, cost: 2033
# Processed 5420000 states; group: 407, pos: -14, cost: None
# Processed 5430000 states; group: 198, pos: -18, cost: 2034
# Processed 5440000 states; group: 171, pos: -9, cost: 2032
# Processed 5450000 states; group: 177, pos: 25, cost: 2036
# Processed 5460000 states; group: 194, pos: 18, cost: 2036
# Processed 5470000 states; group: 436, pos: -24, cost: 2032
# Processed 5480000 states; group: 439, pos: 0, cost: 2033
# Processed 5490000 states; group: 335, pos: -31, cost: 2032
# Processed 5500000 states; group: 166, pos: 30, cost: 2036
# Processed 5510000 states; group: 916, pos: -4, cost: 2033
# Processed 5520000 states; group: 484, pos: -3, cost: 2033
# Processed 5530000 states; group: 337, pos: -15, cost: 2032
# Processed 5540000 states; group: 173, pos: -8, cost: 2032
# Processed 5550000 states; group: 166, pos: -9, cost: 2032
# Processed 5560000 states; group: 163, pos: 19, cost: 2035
# Processed 5570000 states; group: 164, pos: -11, cost: 2032
# Processed 5580000 states; group: 172, pos: 7, cost: 2036
# Processed 5590000 states; group: 157, pos: 49, cost: 2035
# Processed 5600000 states; group: 210, pos: 47, cost: 2035
# Processed 5610000 states; group: 196, pos: 24, cost: 2033
# Processed 5620000 states; group: 172, pos: 42, cost: 2033
# Processed 5630000 states; group: 153, pos: -4, cost: 2032
# Processed 5640000 states; group: 152, pos: 5, cost: 2036
# Processed 5650000 states; group: 153, pos: 45, cost: 2035
# Processed 5660000 states; group: 147, pos: -10, cost: 2032
# Processed 5670000 states; group: 144, pos: 30, cost: 2035
# Processed 5680000 states; group: 143, pos: 14, cost: 2035
# Processed 5690000 states; group: 139, pos: -9, cost: 2032
# Processed 5700000 states; group: 136, pos: 40, cost: 2035
# Processed 5710000 states; group: 152, pos: 5, cost: 2036
# Processed 5720000 states; group: 137, pos: 5, cost: 2034
# Processed 5730000 states; group: 131, pos: 41, cost: 2035
# Processed 5740000 states; group: 442, pos: -8, cost: 2033
# Processed 5750000 states; group: 458, pos: -18, cost: 2032
# Processed 5760000 states; group: 157, pos: -10, cost: 2032
# Processed 5770000 states; group: 125, pos: 28, cost: 2036
# Processed 5780000 states; group: 121, pos: 41, cost: 2036
# Processed 5790000 states; group: 118, pos: 30, cost: 2035
# Processed 5800000 states; group: 132, pos: -21, cost: 2032
# Processed 5810000 states; group: 120, pos: -9, cost: 2034
# Processed 5820000 states; group: 112, pos: 15, cost: 2036
# Processed 5830000 states; group: 172, pos: 3, cost: 2036
# Processed 5840000 states; group: 155, pos: 3, cost: 2036
# Processed 5850000 states; group: 123, pos: 18, cost: 2036
# Processed 5860000 states; group: 157, pos: 21, cost: 2036
# Processed 5870000 states; group: 132, pos: 21, cost: 2035
# Processed 5880000 states; group: 105, pos: 26, cost: 2036
# Processed 5890000 states; group: 102, pos: 22, cost: 2036
# Processed 5900000 states; group: 100, pos: 35, cost: 2036
# Processed 5910000 states; group: 94, pos: -18, cost: 2032
# Processed 5920000 states; group: 89, pos: 29, cost: 2036
# Processed 5930000 states; group: 546, pos: -27, cost: 2032
# Processed 5940000 states; group: 90, pos: 9, cost: 2036
# Processed 5950000 states; group: 87, pos: 24, cost: 2035
# Processed 5960000 states; group: 99, pos: -33, cost: 2033
# Processed 5970000 states; group: 405, pos: -31, cost: 2032
# Processed 5980000 states; group: 330, pos: -33, cost: 2032
# Processed 5990000 states; group: 78, pos: 28, cost: 2035
# Processed 6000000 states; group: 78, pos: -13, cost: 2032
# Processed 6010000 states; group: 74, pos: 18, cost: 2035
# Processed 6020000 states; group: 74, pos: 22, cost: 2035
# Processed 6030000 states; group: 160, pos: -19, cost: 2034
# Processed 6040000 states; group: 78, pos: -14, cost: 2034
# Processed 6050000 states; group: 66, pos: 41, cost: 2035
# Processed 6060000 states; group: 64, pos: 23, cost: 2035
# Processed 6070000 states; group: 78, pos: -29, cost: 2033
# Processed 6080000 states; group: 66, pos: -2, cost: 2032
# Processed 6090000 states; group: 131, pos: 16, cost: 2035
# Processed 6100000 states; group: 61, pos: 9, cost: 2035
# Processed 6110000 states; group: 49, pos: 17, cost: 2035
# Processed 6120000 states; group: 45, pos: 22, cost: 2034
# Processed 6130000 states; group: 38, pos: -23, cost: 2032
# Processed 6140000 states; group: 134, pos: 25, cost: 2036
# Processed 6150000 states; group: 114, pos: -19, cost: 2032
# Processed 6160000 states; group: 101, pos: 25, cost: 2034
# Processed 6170000 states; group: 77, pos: 38, cost: 2033
# Processed 6180000 states; group: 35, pos: 1, cost: 2035
# Processed 6190000 states; group: 51, pos: 27, cost: 2035
# Processed 6200000 states; group: 993, pos: 5, cost: 2037
# Processed 6210000 states; group: 42, pos: 17, cost: 2035
# Processed 6220000 states; group: 780, pos: 0, cost: None
# Processed 6230000 states; group: 422, pos: -15, cost: None
# Processed 6240000 states; group: 327, pos: -2, cost: 2031
# Processed 6250000 states; group: 280, pos: -43, cost: None
# Processed 6260000 states; group: 843, pos: 0, cost: 2033
# Processed 6270000 states; group: 457, pos: -26, cost: 2034
# Processed 6280000 states; group: 70, pos: -3, cost: None
# Processed 6290000 states; group: 779, pos: 22, cost: 2038
# Processed 6300000 states; group: 386, pos: 9, cost: 2037
# Processed 6310000 states; group: 977, pos: -1, cost: None
# Processed 6320000 states; group: 130, pos: 8, cost: 2035
# Processed 6330000 states; group: 481, pos: -14, cost: None
# Processed 6340000 states; group: 660, pos: -2, cost: 2034
# Processed 6350000 states; group: 505, pos: -3, cost: None
# Processed 6360000 states; group: 997, pos: 22, cost: 2038
# Processed 6370000 states; group: 321, pos: -11, cost: 2031
# Processed 6380000 states; group: 340, pos: 0, cost: None
# Processed 6390000 states; group: 379, pos: -16, cost: 2031
# Processed 6400000 states; group: 255, pos: 6, cost: 2036
# Processed 6410000 states; group: 412, pos: 12, cost: 2037
# Processed 6420000 states; group: 666, pos: 28, cost: 2037
# Processed 6430000 states; group: 168, pos: -1, cost: 2031
# Processed 6440000 states; group: 815, pos: 3, cost: 2038
# Processed 6450000 states; group: 246, pos: -17, cost: 2031
# Processed 6460000 states; group: 261, pos: -22, cost: 2031
# Processed 6470000 states; group: 623, pos: -8, cost: None
# Processed 6480000 states; group: 662, pos: -10, cost: None
# Processed 6490000 states; group: 991, pos: -11, cost: 2032
# Processed 6500000 states; group: 376, pos: 0, cost: 2033
# Processed 6510000 states; group: 358, pos: -11, cost: 2033
# Processed 6520000 states; group: 44, pos: -18, cost: None
# Processed 6530000 states; group: 895, pos: -26, cost: 2031
# Processed 6540000 states; group: 333, pos: 16, cost: 2036
# Processed 6550000 states; group: 88, pos: -2, cost: 2032
# Processed 6560000 states; group: 668, pos: 14, cost: 2037
# Processed 6570000 states; group: 637, pos: -22, cost: 2032
# Processed 6580000 states; group: 902, pos: 16, cost: 2036
# Processed 6590000 states; group: 292, pos: 20, cost: 2036
# Processed 6600000 states; group: 175, pos: -28, cost: 2031
# Processed 6610000 states; group: 39, pos: -11, cost: None
# Processed 6620000 states; group: 589, pos: -2, cost: 2031
# Processed 6630000 states; group: 364, pos: -1, cost: 2031
# Processed 6640000 states; group: 768, pos: -13, cost: 2031
# Processed 6650000 states; group: 209, pos: -13, cost: 2032
# Processed 6660000 states; group: 76, pos: -20, cost: None
# Processed 6670000 states; group: 469, pos: -23, cost: 2031
# Processed 6680000 states; group: 40, pos: -2, cost: 2034
# Processed 6690000 states; group: 436, pos: 13, cost: 2038
# Processed 6700000 states; group: 29, pos: -7, cost: 2032
# Processed 6710000 states; group: 30, pos: 19, cost: 2035
# Processed 6720000 states; group: 23, pos: 18, cost: 2035
# Processed 6730000 states; group: 31, pos: 27, cost: 2035
# Processed 6740000 states; group: 28, pos: 9, cost: 2035
# Processed 6750000 states; group: 16, pos: 40, cost: 2035
# Processed 6760000 states; group: 738, pos: 1, cost: 2032
# Processed 6770000 states; group: 157, pos: 24, cost: 2036
# Processed 6780000 states; group: 993, pos: 16, cost: 2037
# Processed 6790000 states; group: 49, pos: 23, cost: 2035
# Processed 6800000 states; group: 12, pos: 33, cost: 2034
# Processed 6810000 states; group: 9, pos: 7, cost: 2033
# Processed 6820000 states; group: 562, pos: 3, cost: 2037
# Processed 6830000 states; group: 8, pos: 1, cost: 2035
# Processed 6840000 states; group: 476, pos: 22, cost: 2035
# Processed 6850000 states; group: 5, pos: 0, cost: None
# Processed 6860000 states; group: 3, pos: -7, cost: 2032
# Processed 10000 states; group: 998, pos: -23, cost: 9995
# Processed 20000 states; group: 998, pos: 14, cost: 10004
# Processed 30000 states; group: 998, pos: 19, cost: 10004
# Processed 40000 states; group: 1000, pos: 3, cost: 10005
# Processed 50000 states; group: 993, pos: 22, cost: 10005
# Processed 60000 states; group: 999, pos: 25, cost: 10004
# Processed 70000 states; group: 989, pos: 7, cost: 10005
# Processed 80000 states; group: 992, pos: 17, cost: 10004
# Processed 90000 states; group: 989, pos: -19, cost: 9996
# Processed 100000 states; group: 990, pos: -4, cost: 10004
# Processed 110000 states; group: 986, pos: -18, cost: 9995
# Processed 120000 states; group: 985, pos: 21, cost: 10005
# Processed 130000 states; group: 995, pos: 15, cost: 10002
# Processed 140000 states; group: 983, pos: -6, cost: 10000
# Processed 150000 states; group: 981, pos: 32, cost: 10005
# Processed 160000 states; group: 982, pos: 31, cost: 10004
# Processed 170000 states; group: 988, pos: -20, cost: 9998
# Processed 180000 states; group: 975, pos: 37, cost: 10005
# Processed 190000 states; group: 981, pos: 27, cost: 10005
# Processed 200000 states; group: 969, pos: 19, cost: 10005
# Processed 210000 states; group: 977, pos: 7, cost: 10005
# Processed 220000 states; group: 968, pos: -29, cost: 9996
# Processed 230000 states; group: 968, pos: 25, cost: 10004
# Processed 240000 states; group: 983, pos: 49, cost: 10002
# Processed 250000 states; group: 972, pos: 17, cost: 10005
# Processed 260000 states; group: 972, pos: -5, cost: 9999
# Processed 270000 states; group: 971, pos: 21, cost: 10004
# Processed 280000 states; group: 968, pos: -9, cost: 9999
# Processed 290000 states; group: 965, pos: 44, cost: 10004
# Processed 300000 states; group: 961, pos: 17, cost: 10005
# Processed 310000 states; group: 970, pos: 3, cost: 10000
# Processed 320000 states; group: 961, pos: 10, cost: 10005
# Processed 330000 states; group: 968, pos: -6, cost: 9999
# Processed 340000 states; group: 958, pos: 14, cost: 10004
# Processed 350000 states; group: 954, pos: 16, cost: 10005
# Processed 360000 states; group: 979, pos: 37, cost: 10001
# Processed 370000 states; group: 952, pos: -8, cost: 9998
# Processed 380000 states; group: 962, pos: 48, cost: 10003
# Processed 390000 states; group: 952, pos: -13, cost: 9996
# Processed 400000 states; group: 950, pos: -21, cost: 9998
# Processed 410000 states; group: 946, pos: 5, cost: 10005
# Processed 420000 states; group: 951, pos: 19, cost: 10003
# Processed 430000 states; group: 949, pos: -8, cost: 9997
# Processed 440000 states; group: 961, pos: 22, cost: 10003
# Processed 450000 states; group: 954, pos: 40, cost: 10003
# Processed 460000 states; group: 991, pos: 46, cost: 10001
# Processed 470000 states; group: 961, pos: 32, cost: 10003
# Processed 480000 states; group: 955, pos: 1, cost: 10005
# Processed 490000 states; group: 955, pos: 37, cost: 10003
# Processed 500000 states; group: 970, pos: 43, cost: 10000
# Processed 510000 states; group: 996, pos: 19, cost: 9998
# Processed 520000 states; group: 945, pos: 13, cost: 10005
# Processed 530000 states; group: 942, pos: 50, cost: 10003
# Processed 540000 states; group: 977, pos: 11, cost: 10005
# Processed 550000 states; group: 948, pos: -3, cost: 10000
# Processed 560000 states; group: 938, pos: -3, cost: 9998
# Processed 570000 states; group: 945, pos: -10, cost: 10000
# Processed 580000 states; group: 938, pos: 2, cost: 10004
# Processed 590000 states; group: 939, pos: -10, cost: 9995
# Processed 600000 states; group: 960, pos: -3, cost: 9998
# Processed 610000 states; group: 933, pos: 30, cost: 10005
# Processed 620000 states; group: 941, pos: 11, cost: 10003
# Processed 630000 states; group: 931, pos: -1, cost: 9995
# Processed 640000 states; group: 929, pos: -5, cost: None
# Processed 650000 states; group: 927, pos: 18, cost: 10004
# Processed 660000 states; group: 980, pos: 3, cost: 10005
# Processed 670000 states; group: 930, pos: -13, cost: None
# Processed 680000 states; group: 926, pos: 42, cost: 10004
# Processed 690000 states; group: 943, pos: -6, cost: None
# Processed 700000 states; group: 926, pos: -2, cost: None
# Processed 710000 states; group: 938, pos: 14, cost: 10005
# Processed 720000 states; group: 925, pos: 8, cost: 10002
# Processed 730000 states; group: 924, pos: -22, cost: 9995
# Processed 740000 states; group: 921, pos: -10, cost: 9998
# Processed 750000 states; group: 924, pos: 18, cost: 10003
# Processed 760000 states; group: 919, pos: 36, cost: 10003
# Processed 770000 states; group: 917, pos: 3, cost: 10004
# Processed 780000 states; group: 922, pos: 36, cost: 10004
# Processed 790000 states; group: 922, pos: -12, cost: 10002
# Processed 800000 states; group: 925, pos: -18, cost: 10000
# Processed 810000 states; group: 918, pos: -21, cost: 9999
# Processed 820000 states; group: 933, pos: 18, cost: 10005
# Processed 830000 states; group: 921, pos: 21, cost: 10003
# Processed 840000 states; group: 923, pos: -14, cost: 9999
# Processed 850000 states; group: 917, pos: -13, cost: 9998
# Processed 860000 states; group: 915, pos: -29, cost: None
# Processed 870000 states; group: 935, pos: 21, cost: 10005
# Processed 880000 states; group: 918, pos: 4, cost: 9999
# Processed 890000 states; group: 914, pos: 7, cost: 10005
# Processed 900000 states; group: 916, pos: -3, cost: 9995
# Processed 910000 states; group: 922, pos: -14, cost: 9999
# Processed 920000 states; group: 911, pos: 14, cost: 10000
# Processed 930000 states; group: 932, pos: 6, cost: 10003
# Processed 940000 states; group: 938, pos: -7, cost: 10004
# Processed 950000 states; group: 912, pos: 7, cost: 10005
# Processed 960000 states; group: 909, pos: -24, cost: 9995
# Processed 970000 states; group: 915, pos: -4, cost: 10003
# Processed 980000 states; group: 907, pos: 16, cost: 10005
# Processed 990000 states; group: 911, pos: -7, cost: 9997
# Processed 1000000 states; group: 904, pos: -6, cost: 9998
# Processed 1010000 states; group: 949, pos: 38, cost: 10000
# Processed 1020000 states; group: 905, pos: 5, cost: 10005
# Processed 1030000 states; group: 910, pos: -13, cost: 9996
# Processed 1040000 states; group: 900, pos: 25, cost: 10005
# Processed 1050000 states; group: 904, pos: 15, cost: 10005
# Processed 1060000 states; group: 898, pos: 43, cost: 10004
# Processed 1070000 states; group: 893, pos: 13, cost: 10004
# Processed 1080000 states; group: 908, pos: 38, cost: 10003
# Processed 1090000 states; group: 936, pos: 37, cost: 10000
# Processed 1100000 states; group: 889, pos: -12, cost: None
# Processed 1110000 states; group: 899, pos: 6, cost: 10005
# Processed 1120000 states; group: 891, pos: 37, cost: 10003
# Processed 1130000 states; group: 925, pos: 16, cost: 9999
# Processed 1140000 states; group: 904, pos: 47, cost: 10003
# Processed 1150000 states; group: 907, pos: 37, cost: 10003
# Processed 1160000 states; group: 886, pos: 17, cost: 10005
# Processed 1170000 states; group: 902, pos: 8, cost: 10004
# Processed 1180000 states; group: 884, pos: -35, cost: 9996
# Processed 1190000 states; group: 883, pos: 33, cost: 10004
# Processed 1200000 states; group: 960, pos: 33, cost: 10002
# Processed 1210000 states; group: 894, pos: 28, cost: 10002
# Processed 1220000 states; group: 897, pos: -10, cost: 9995
# Processed 1230000 states; group: 902, pos: 2, cost: 9998
# Processed 1240000 states; group: 884, pos: 24, cost: 10005
# Processed 1250000 states; group: 911, pos: -8, cost: 9997
# Processed 1260000 states; group: 881, pos: 34, cost: 10003
# Processed 1270000 states; group: 882, pos: -8, cost: 10002
# Processed 1280000 states; group: 937, pos: -18, cost: 9995
# Processed 1290000 states; group: 906, pos: 44, cost: 10000
# Processed 1300000 states; group: 883, pos: 30, cost: 10002
# Processed 1310000 states; group: 982, pos: 6, cost: 10005
# Processed 1320000 states; group: 880, pos: 11, cost: 10000
# Processed 1330000 states; group: 926, pos: 2, cost: 9997
# Processed 1340000 states; group: 970, pos: 21, cost: 9997
# Processed 1350000 states; group: 937, pos: 2, cost: 9997
# Processed 1360000 states; group: 994, pos: 50, cost: 9997
# Processed 1370000 states; group: 903, pos: 29, cost: 10002
# Processed 1380000 states; group: 967, pos: -1, cost: 10000
# Processed 1390000 states; group: 917, pos: 22, cost: 10002
# Processed 1400000 states; group: 877, pos: 0, cost: 10004
# Processed 1410000 states; group: 909, pos: 24, cost: 10000
# Processed 1420000 states; group: 876, pos: 38, cost: 10002
# Processed 1430000 states; group: 873, pos: 25, cost: 10005
# ...
# {'timestamp': 39100, 'price': 1852, 'quantity': -1}
# {'timestamp': 39200, 'price': 1850, 'quantity': 8}
# {'timestamp': 39500, 'price': 1849, 'quantity': 6}
# {'timestamp': 39500, 'price': 1851, 'quantity': 3}
# {'timestamp': 39700, 'price': 1850, 'quantity': 12}
# {'timestamp': 39700, 'price': 1852, 'quantity': 17}
# {'timestamp': 39700, 'price': 1849, 'quantity': -29}
# {'timestamp': 39900, 'price': 1851, 'quantity': 11}
# {'timestamp': 40000, 'price': 1850, 'quantity': 14}
# {'timestamp': 40000, 'price': 1852, 'quantity': 6}
# {'timestamp': 40200, 'price': 1854, 'quantity': 6}
# {'timestamp': 40400, 'price': 1852, 'quantity': -6}
# {'timestamp': 40500, 'price': 1854, 'quantity': 6}
# {'timestamp': 41000, 'price': 1852, 'quantity': -5}
# {'timestamp': 41100, 'price': 1854, 'quantity': 6}
# {'timestamp': 41300, 'price': 1857, 'quantity': -7}
# {'timestamp': 41300, 'price': 1856, 'quantity': -37}
# {'timestamp': 41400, 'price': 1858, 'quantity': 18}
# {'timestamp': 41400, 'price': 1855, 'quantity': -15}
# {'timestamp': 41500, 'price': 1857, 'quantity': 16}
# {'timestamp': 41600, 'price': 1856, 'quantity': 26}
# {'timestamp': 41700, 'price': 1859, 'quantity': -4}
# {'timestamp': 41700, 'price': 1857, 'quantity': -3}
# {'timestamp': 41900, 'price': 1859, 'quantity': 7}
# {'timestamp': 42000, 'price': 1858, 'quantity': -1}
# {'timestamp': 42000, 'price': 1857, 'quantity': -6}
# {'timestamp': 42100, 'price': 1860, 'quantity': 6}
# {'timestamp': 42300, 'price': 1860, 'quantity': -19}
# {'timestamp': 42600, 'price': 1861, 'quantity': 11}
# {'timestamp': 42800, 'price': 1859, 'quantity': 4}
# {'timestamp': 42800, 'price': 1861, 'quantity': 4}
# {'timestamp': 43000, 'price': 1864, 'quantity': -39}
# {'timestamp': 43100, 'price': 1865, 'quantity': -2}
# {'timestamp': 43100, 'price': 1864, 'quantity': -34}
# {'timestamp': 43200, 'price': 1863, 'quantity': -8}
# {'timestamp': 43400, 'price': 1863, 'quantity': 42}
# {'timestamp': 43400, 'price': 1860, 'quantity': -24}
# {'timestamp': 43500, 'price': 1861, 'quantity': -48}
# {'timestamp': 51400, 'price': 1831, 'quantity': 8}
# {'timestamp': 51600, 'price': 1831, 'quantity': 7}
# {'timestamp': 52000, 'price': 1830, 'quantity': 8}
# {'timestamp': 52100, 'price': 1830, 'quantity': 28}
# {'timestamp': 52100, 'price': 1827, 'quantity': -28}
# {'timestamp': 52200, 'price': 1830, 'quantity': 10}
# {'timestamp': 52300, 'price': 1831, 'quantity': 15}
# {'timestamp': 53000, 'price': 1840, 'quantity': -1}
# {'timestamp': 53000, 'price': 1839, 'quantity': -7}
# {'timestamp': 53200, 'price': 1841, 'quantity': 6}
# {'timestamp': 53300, 'price': 1840, 'quantity': -5}
# {'timestamp': 53400, 'price': 1843, 'quantity': 4}
# {'timestamp': 53400, 'price': 1841, 'quantity': -14}
# {'timestamp': 53500, 'price': 1840, 'quantity': -14}
# {'timestamp': 53700, 'price': 1841, 'quantity': -11}
# {'timestamp': 53700, 'price': 1840, 'quantity': -29}
# {'timestamp': 53900, 'price': 1839, 'quantity': 8}
# {'timestamp': 54000, 'price': 1840, 'quantity': 11}
# {'timestamp': 54100, 'price': 1841, 'quantity': 25}
# {'timestamp': 54100, 'price': 1840, 'quantity': -2}
# {'timestamp': 54500, 'price': 1838, 'quantity': 22}
# {'timestamp': 54500, 'price': 1836, 'quantity': -8}
# {'timestamp': 54500, 'price': 1835, 'quantity': -22}
# {'timestamp': 54600, 'price': 1839, 'quantity': 14}
# {'timestamp': 54700, 'price': 1842, 'quantity': 6}
# {'timestamp': 54800, 'price': 1840, 'quantity': -32}
# {'timestamp': 55100, 'price': 1839, 'quantity': -9}
# {'timestamp': 55300, 'price': 1838, 'quantity': 6}
# {'timestamp': 55300, 'price': 1839, 'quantity': 13}
# {'timestamp': 55400, 'price': 1839, 'quantity': 21}
# {'timestamp': 55500, 'price': 1840, 'quantity': -18}
# {'timestamp': 55600, 'price': 1840, 'quantity': -19}
# {'timestamp': 55700, 'price': 1840, 'quantity': -11}
# {'timestamp': 55800, 'price': 1839, 'quantity': -50}
# {'timestamp': 56000, 'price': 1838, 'quantity': 10}
# {'timestamp': 56200, 'price': 1835, 'quantity': 8}
# {'timestamp': 56200, 'price': 1837, 'quantity': 31}
# {'timestamp': 56200, 'price': 1834, 'quantity': -31}
# {'timestamp': 56500, 'price': 1839, 'quantity': 20}
# {'timestamp': 57200, 'price': 1847, 'quantity': -26}
# {'timestamp': 57300, 'price': 1847, 'quantity': -23}
# {'timestamp': 57400, 'price': 1846, 'quantity': -44}
# {'timestamp': 58200, 'price': 1840, 'quantity': 29}
# {'timestamp': 58300, 'price': 1840, 'quantity': 30}
# {'timestamp': 58300, 'price': 1836, 'quantity': -30}
# {'timestamp': 58400, 'price': 1840, 'quantity': 25}
# {'timestamp': 58500, 'price': 1841, 'quantity': -22}
# {'timestamp': 58600, 'price': 1840, 'quantity': -39}
# {'timestamp': 58700, 'price': 1839, 'quantity': 8}
# {'timestamp': 58700, 'price': 1838, 'quantity': -2}
# {'timestamp': 58800, 'price': 1839, 'quantity': 10}
# {'timestamp': 58800, 'price': 1840, 'quantity': -1}
# {'timestamp': 58800, 'price': 1839, 'quantity': -1}
# {'timestamp': 58800, 'price': 1837, 'quantity': -33}
# {'timestamp': 58900, 'price': 1842, 'quantity': 10}
# {'timestamp': 59000, 'price': 1842, 'quantity': 7}
# {'timestamp': 59200, 'price': 1843, 'quantity': 6}
# {'timestamp': 59200, 'price': 1842, 'quantity': -13}
# {'timestamp': 59500, 'price': 1844, 'quantity': 6}
# {'timestamp': 59600, 'price': 1842, 'quantity': -1}
# {'timestamp': 59600, 'price': 1841, 'quantity': -5}
# {'timestamp': 59700, 'price': 1843, 'quantity': 6}
# {'timestamp': 59700, 'price': 1844, 'quantity': -2}
# {'timestamp': 59800, 'price': 1843, 'quantity': -20}
# {'timestamp': 59900, 'price': 1845, 'quantity': -27}
# {'timestamp': 60100, 'price': 1845, 'quantity': -28}
# {'timestamp': 60300, 'price': 1842, 'quantity': 6}
# {'timestamp': 60400, 'price': 1842, 'quantity': 24}
# {'timestamp': 60400, 'price': 1839, 'quantity': -24}
# {'timestamp': 60700, 'price': 1842, 'quantity': -10}
# {'timestamp': 61500, 'price': 1844, 'quantity': -2}
# {'timestamp': 61500, 'price': 1842, 'quantity': -10}
# {'timestamp': 61600, 'price': 1844, 'quantity': -44}
# {'timestamp': 62900, 'price': 1837, 'quantity': 25}
# {'timestamp': 63400, 'price': 1837, 'quantity': 18}
# {'timestamp': 63600, 'price': 1839, 'quantity': 44}
# {'timestamp': 63600, 'price': 1838, 'quantity': -2}
# {'timestamp': 64000, 'price': 1834, 'quantity': 47}
# {'timestamp': 64000, 'price': 1831, 'quantity': -34}
# {'timestamp': 64100, 'price': 1835, 'quantity': 8}
# {'timestamp': 64100, 'price': 1837, 'quantity': 1}
# {'timestamp': 64300, 'price': 1836, 'quantity': 12}
# {'timestamp': 64700, 'price': 1839, 'quantity': -45}
# {'timestamp': 64900, 'price': 1841, 'quantity': 43}
# {'timestamp': 64900, 'price': 1838, 'quantity': -48}
# {'timestamp': 65000, 'price': 1842, 'quantity': 40}
# {'timestamp': 65000, 'price': 1841, 'quantity': -2}
# {'timestamp': 67200, 'price': 1835, 'quantity': 10}
# {'timestamp': 67700, 'price': 1832, 'quantity': 6}
# {'timestamp': 67700, 'price': 1834, 'quantity': 23}
# {'timestamp': 67700, 'price': 1831, 'quantity': -29}
# {'timestamp': 67900, 'price': 1835, 'quantity': 23}
# {'timestamp': 68200, 'price': 1838, 'quantity': 6}
# {'timestamp': 68200, 'price': 1836, 'quantity': -1}
# {'timestamp': 68200, 'price': 1835, 'quantity': -5}
# {'timestamp': 68600, 'price': 1838, 'quantity': -32}
# {'timestamp': 68700, 'price': 1838, 'quantity': -11}
# {'timestamp': 68800, 'price': 1838, 'quantity': 11}
# {'timestamp': 68900, 'price': 1838, 'quantity': 25}
# {'timestamp': 69100, 'price': 1838, 'quantity': 1}
# {'timestamp': 69100, 'price': 1840, 'quantity': 6}
# {'timestamp': 69400, 'price': 1839, 'quantity': -4}
# {'timestamp': 69400, 'price': 1838, 'quantity': -2}
# {'timestamp': 70300, 'price': 1841, 'quantity': 6}
# {'timestamp': 70600, 'price': 1840, 'quantity': -4}
# {'timestamp': 70600, 'price': 1839, 'quantity': -13}
# {'timestamp': 71000, 'price': 1838, 'quantity': 2}
# {'timestamp': 71000, 'price': 1840, 'quantity': 6}
# {'timestamp': 71100, 'price': 1840, 'quantity': 8}
# {'timestamp': 71200, 'price': 1838, 'quantity': -7}
# {'timestamp': 71400, 'price': 1839, 'quantity': 12}
# {'timestamp': 71400, 'price': 1838, 'quantity': -4}
# {'timestamp': 71700, 'price': 1844, 'quantity': 1}
# {'timestamp': 71700, 'price': 1844, 'quantity': -2}
# {'timestamp': 72000, 'price': 1844, 'quantity': -6}
# {'timestamp': 72200, 'price': 1844, 'quantity': -36}
# {'timestamp': 72600, 'price': 1844, 'quantity': -7}
# {'timestamp': 72700, 'price': 1845, 'quantity': -44}
# {'timestamp': 74400, 'price': 1832, 'quantity': 4}
# {'timestamp': 74400, 'price': 1833, 'quantity': 2}
# {'timestamp': 74600, 'price': 1832, 'quantity': 1}
# {'timestamp': 74600, 'price': 1833, 'quantity': 7}
# {'timestamp': 75000, 'price': 1831, 'quantity': 1}
# {'timestamp': 75000, 'price': 1833, 'quantity': 27}
# {'timestamp': 75500, 'price': 1832, 'quantity': 2}
# {'timestamp': 75500, 'price': 1834, 'quantity': 23}
# {'timestamp': 75500, 'price': 1831, 'quantity': -25}
# {'timestamp': 75800, 'price': 1835, 'quantity': 8}
# {'timestamp': 75800, 'price': 1834, 'quantity': -2}
# {'timestamp': 75800, 'price': 1832, 'quantity': -8}
# {'timestamp': 76000, 'price': 1834, 'quantity': -50}
# {'timestamp': 76900, 'price': 1823, 'quantity': 14}
# {'timestamp': 77000, 'price': 1817, 'quantity': 8}
# {'timestamp': 77000, 'price': 1819, 'quantity': 28}
# {'timestamp': 77000, 'price': 1815, 'quantity': -28}
# {'timestamp': 77400, 'price': 1825, 'quantity': -10}
# {'timestamp': 77400, 'price': 1823, 'quantity': -24}
# {'timestamp': 77500, 'price': 1823, 'quantity': -6}
# {'timestamp': 77700, 'price': 1822, 'quantity': -47}
# {'timestamp': 80300, 'price': 1806, 'quantity': 8}
# {'timestamp': 80600, 'price': 1803, 'quantity': 4}
# {'timestamp': 80600, 'price': 1804, 'quantity': 40}
# {'timestamp': 80600, 'price': 1801, 'quantity': -41}
# {'timestamp': 80800, 'price': 1805, 'quantity': -36}
# {'timestamp': 80900, 'price': 1806, 'quantity': -40}
# {'timestamp': 81000, 'price': 1803, 'quantity': 43}
# {'timestamp': 81000, 'price': 1800, 'quantity': -43}
# {'timestamp': 81100, 'price': 1805, 'quantity': 9}
# {'timestamp': 81800, 'price': 1812, 'quantity': -21}
# {'timestamp': 81900, 'price': 1811, 'quantity': -22}
# {'timestamp': 82000, 'price': 1812, 'quantity': -6}
# {'timestamp': 82100, 'price': 1810, 'quantity': -42}
# {'timestamp': 82500, 'price': 1804, 'quantity': 18}
# {'timestamp': 82600, 'price': 1804, 'quantity': 24}
# {'timestamp': 82600, 'price': 1803, 'quantity': -31}
# {'timestamp': 82700, 'price': 1805, 'quantity': -51}
# {'timestamp': 82800, 'price': 1804, 'quantity': -21}
# {'timestamp': 82900, 'price': 1807, 'quantity': 8}
# {'timestamp': 82900, 'price': 1804, 'quantity': -9}
# {'timestamp': 83000, 'price': 1806, 'quantity': -41}
# {'timestamp': 84300, 'price': 1800, 'quantity': 5}
# {'timestamp': 84500, 'price': 1800, 'quantity': 6}
# {'timestamp': 84600, 'price': 1798, 'quantity': 30}
# {'timestamp': 84600, 'price': 1796, 'quantity': -1}
# {'timestamp': 84600, 'price': 1795, 'quantity': -29}
# {'timestamp': 84700, 'price': 1802, 'quantity': 13}
# {'timestamp': 84800, 'price': 1802, 'quantity': 6}
# {'timestamp': 85300, 'price': 1808, 'quantity': -12}
# {'timestamp': 85400, 'price': 1808, 'quantity': -6}
# {'timestamp': 85500, 'price': 1808, 'quantity': 10}
# {'timestamp': 85500, 'price': 1809, 'quantity': 8}
# {'timestamp': 85900, 'price': 1813, 'quantity': -18}
# {'timestamp': 86000, 'price': 1815, 'quantity': -8}
# {'timestamp': 86000, 'price': 1814, 'quantity': -23}
# {'timestamp': 86200, 'price': 1814, 'quantity': -44}
# {'timestamp': 88200, 'price': 1808, 'quantity': 30}
# {'timestamp': 88300, 'price': 1808, 'quantity': 8}
# {'timestamp': 88600, 'price': 1807, 'quantity': 8}
# {'timestamp': 88600, 'price': 1808, 'quantity': 2}
# {'timestamp': 88600, 'price': 1809, 'quantity': 30}
# {'timestamp': 88600, 'price': 1806, 'quantity': -45}
# {'timestamp': 88900, 'price': 1808, 'quantity': -17}
# {'timestamp': 88900, 'price': 1807, 'quantity': -27}
# {'timestamp': 89600, 'price': 1806, 'quantity': 9}
# {'timestamp': 89800, 'price': 1807, 'quantity': 14}
# {'timestamp': 89900, 'price': 1809, 'quantity': 60}
# {'timestamp': 89900, 'price': 1808, 'quantity': -1}
# {'timestamp': 90100, 'price': 1806, 'quantity': 16}
# {'timestamp': 90100, 'price': 1808, 'quantity': 3}
# {'timestamp': 90200, 'price': 1805, 'quantity': 12}
# {'timestamp': 90200, 'price': 1807, 'quantity': 26}
# {'timestamp': 90200, 'price': 1806, 'quantity': -1}
# {'timestamp': 90200, 'price': 1804, 'quantity': -3}
# {'timestamp': 90200, 'price': 1803, 'quantity': -28}
# {'timestamp': 90300, 'price': 1808, 'quantity': 7}
# {'timestamp': 90400, 'price': 1807, 'quantity': 8}
# {'timestamp': 90400, 'price': 1808, 'quantity': 4}
# {'timestamp': 90500, 'price': 1809, 'quantity': -1}
# {'timestamp': 90500, 'price': 1808, 'quantity': -16}
# {'timestamp': 90500, 'price': 1807, 'quantity': -28}
# {'timestamp': 90700, 'price': 1809, 'quantity': 31}
# {'timestamp': 90700, 'price': 1808, 'quantity': -1}
# {'timestamp': 91300, 'price': 1802, 'quantity': 14}
# {'timestamp': 91300, 'price': 1804, 'quantity': 22}
# {'timestamp': 91300, 'price': 1800, 'quantity': -26}
# {'timestamp': 91400, 'price': 1804, 'quantity': 6}
# {'timestamp': 91600, 'price': 1803, 'quantity': 22}
# {'timestamp': 92800, 'price': 1814, 'quantity': -9}
# {'timestamp': 92800, 'price': 1813, 'quantity': -33}
# {'timestamp': 93100, 'price': 1812, 'quantity': 4}
# {'timestamp': 93100, 'price': 1814, 'quantity': 4}
# {'timestamp': 93300, 'price': 1811, 'quantity': 14}
# {'timestamp': 93300, 'price': 1813, 'quantity': 23}
# {'timestamp': 93500, 'price': 1817, 'quantity': -10}
# {'timestamp': 93700, 'price': 1818, 'quantity': -30}
# {'timestamp': 93800, 'price': 1816, 'quantity': 8}
# {'timestamp': 94300, 'price': 1815, 'quantity': -10}
# {'timestamp': 94500, 'price': 1815, 'quantity': 18}
# {'timestamp': 94600, 'price': 1815, 'quantity': 22}
# {'timestamp': 94700, 'price': 1819, 'quantity': -2}
# {'timestamp': 94700, 'price': 1818, 'quantity': -1}
# {'timestamp': 94700, 'price': 1817, 'quantity': -3}
# {'timestamp': 94800, 'price': 1816, 'quantity': 2}
# {'timestamp': 94800, 'price': 1818, 'quantity': 4}
# {'timestamp': 94900, 'price': 1818, 'quantity': -30}
# {'timestamp': 95500, 'price': 1815, 'quantity': 6}
# {'timestamp': 95500, 'price': 1816, 'quantity': 3}
# {'timestamp': 95600, 'price': 1816, 'quantity': 5}
# {'timestamp': 95800, 'price': 1816, 'quantity': 10}
# {'timestamp': 96000, 'price': 1816, 'quantity': 9}
# {'timestamp': 96100, 'price': 1816, 'quantity': -2}
# {'timestamp': 96100, 'price': 1814, 'quantity': -8}
# {'timestamp': 96200, 'price': 1817, 'quantity': 8}
# {'timestamp': 96400, 'price': 1816, 'quantity': 3}
# {'timestamp': 96400, 'price': 1816, 'quantity': -14}
# {'timestamp': 96500, 'price': 1815, 'quantity': -10}
# {'timestamp': 96700, 'price': 1815, 'quantity': 4}
# {'timestamp': 96700, 'price': 1816, 'quantity': 2}
# {'timestamp': 96700, 'price': 1817, 'quantity': 3}
# {'timestamp': 96800, 'price': 1816, 'quantity': 8}
# {'timestamp': 97100, 'price': 1815, 'quantity': -20}
# {'timestamp': 97300, 'price': 1815, 'quantity': 21}
# {'timestamp': 97400, 'price': 1816, 'quantity': -2}
# {'timestamp': 97400, 'price': 1814, 'quantity': -6}
# {'timestamp': 97500, 'price': 1816, 'quantity': 12}
# {'timestamp': 97600, 'price': 1816, 'quantity': -8}
# {'timestamp': 97600, 'price': 1815, 'quantity': -1}
# {'timestamp': 97700, 'price': 1815, 'quantity': -14}
# {'timestamp': 98200, 'price': 1815, 'quantity': 6}
# {'timestamp': 98200, 'price': 1817, 'quantity': 4}
# {'timestamp': 98300, 'price': 1816, 'quantity': 6}
# {'timestamp': 98300, 'price': 1818, 'quantity': 1}
# {'timestamp': 98300, 'price': 1815, 'quantity': -8}
# {'timestamp': 98400, 'price': 1815, 'quantity': -31}
# {'timestamp': 98500, 'price': 1816, 'quantity': -32}
# {'timestamp': 99000, 'price': 1812, 'quantity': 28}
# {'timestamp': 99000, 'price': 1810, 'quantity': -1}
# {'timestamp': 99000, 'price': 1809, 'quantity': -27}
# {'timestamp': 99100, 'price': 1814, 'quantity': 6}
# {'timestamp': 99200, 'price': 1812, 'quantity': 2}
# {'timestamp': 99200, 'price': 1814, 'quantity': 12}
# {'timestamp': 99300, 'price': 1816, 'quantity': 6}
# {'timestamp': 99300, 'price': 1814, 'quantity': -2}
# {'timestamp': 99300, 'price': 1813, 'quantity': -2}
# {'timestamp': 99300, 'price': 1812, 'quantity': -2}
# {'timestamp': 99600, 'price': 1817, 'quantity': -10}
# {'timestamp': 99900, 'price': 1819, 'quantity': 39}
# {'timestamp': 99900, 'price': 1816, 'quantity': -43}
# ----------------------------------------

# %%
results['SQUID_INK']
# Out:
# {'profit': 21911,
#  'trades': [{'timestamp': 100, 'price': 1837, 'quantity': -2},
#   {'timestamp': 100, 'price': 1836, 'quantity': -2},
#   {'timestamp': 100, 'price': 1835, 'quantity': -2},
#   {'timestamp': 300, 'price': 1837, 'quantity': 37},
#   {'timestamp': 300, 'price': 1836, 'quantity': -2},
#   {'timestamp': 400, 'price': 1836, 'quantity': 7},
#   {'timestamp': 500, 'price': 1834, 'quantity': -6},
#   {'timestamp': 600, 'price': 1833, 'quantity': 14},
#   {'timestamp': 600, 'price': 1834, 'quantity': -10},
#   {'timestamp': 600, 'price': 1832, 'quantity': -36},
#   {'timestamp': 700, 'price': 1837, 'quantity': 2},
#   {'timestamp': 700, 'price': 1838, 'quantity': 4},
#   {'timestamp': 1400, 'price': 1842, 'quantity': 9},
#   {'timestamp': 1400, 'price': 1841, 'quantity': -9},
#   {'timestamp': 1500, 'price': 1844, 'quantity': -2},
#   {'timestamp': 1500, 'price': 1842, 'quantity': -5},
#   {'timestamp': 1600, 'price': 1844, 'quantity': -4},
#   {'timestamp': 1600, 'price': 1843, 'quantity': -28},
#   {'timestamp': 1700, 'price': 1843, 'quantity': 16},
#   {'timestamp': 1700, 'price': 1844, 'quantity': 17},
#   {'timestamp': 1800, 'price': 1845, 'quantity': 6},
#   {'timestamp': 2000, 'price': 1846, 'quantity': -13},
#   {'timestamp': 2100, 'price': 1847, 'quantity': 10},
#   {'timestamp': 2300, 'price': 1848, 'quantity': -7},
#   {'timestamp': 2400, 'price': 1849, 'quantity': 10},
#   {'timestamp': 2600, 'price': 1850, 'quantity': -1},
#   {'timestamp': 2600, 'price': 1849, 'quantity': -22},
#   {'timestamp': 2700, 'price': 1851, 'quantity': 12},
#   {'timestamp': 2800, 'price': 1849, 'quantity': -7},
#   {'timestamp': 2900, 'price': 1851, 'quantity': 10},
#   {'timestamp': 3200, 'price': 1849, 'quantity': 8},
#   {'timestamp': 4100, 'price': 1857, 'quantity': 6},
#   {'timestamp': 4100, 'price': 1855, 'quantity': -10},
#   {'timestamp': 4200, 'price': 1854, 'quantity': -7},
#   {'timestamp': 4500, 'price': 1854, 'quantity': 10},
#   {'timestamp': 4600, 'price': 1858, 'quantity': 6},
#   {'timestamp': 4600, 'price': 1860, 'quantity': 1},
#   {'timestamp': 4600, 'price': 1857, 'quantity': -7},
#   {'timestamp': 4800, 'price': 1861, 'quantity': -2},
#   {'timestamp': 4800, 'price': 1860, 'quantity': -7},
#   {'timestamp': 4800, 'price': 1859, 'quantity': -23},
#   {'timestamp': 4900, 'price': 1859, 'quantity': 9},
#   {'timestamp': 5000, 'price': 1860, 'quantity': -12},
#   {'timestamp': 5000, 'price': 1859, 'quantity': -9},
#   {'timestamp': 5300, 'price': 1860, 'quantity': 20},
#   {'timestamp': 5400, 'price': 1860, 'quantity': 8},
#   {'timestamp': 5500, 'price': 1859, 'quantity': 11},
#   {'timestamp': 5600, 'price': 1860, 'quantity': -5},
#   {'timestamp': 5600, 'price': 1859, 'quantity': -3},
#   {'timestamp': 5900, 'price': 1860, 'quantity': 12},
#   {'timestamp': 6100, 'price': 1862, 'quantity': 6},
#   {'timestamp': 6100, 'price': 1859, 'quantity': -6},
#   {'timestamp': 6200, 'price': 1861, 'quantity': -2},
#   {'timestamp': 6200, 'price': 1859, 'quantity': -6},
#   {'timestamp': 6300, 'price': 1861, 'quantity': -9},
#   {'timestamp': 6500, 'price': 1860, 'quantity': -10},
#   {'timestamp': 6600, 'price': 1860, 'quantity': -22},
#   {'timestamp': 6700, 'price': 1861, 'quantity': 14},
#   {'timestamp': 6700, 'price': 1862, 'quantity': 31},
#   {'timestamp': 6700, 'price': 1861, 'quantity': -1},
#   {'timestamp': 9100, 'price': 1858, 'quantity': 6},
#   {'timestamp': 9300, 'price': 1857, 'quantity': 12},
#   {'timestamp': 9500, 'price': 1856, 'quantity': 26},
#   {'timestamp': 9500, 'price': 1854, 'quantity': -1},
#   {'timestamp': 9500, 'price': 1853, 'quantity': -25},
#   {'timestamp': 9700, 'price': 1856, 'quantity': 10},
#   {'timestamp': 9700, 'price': 1857, 'quantity': 5},
#   {'timestamp': 9700, 'price': 1858, 'quantity': 8},
#   {'timestamp': 9900, 'price': 1858, 'quantity': -6},
#   {'timestamp': 10100, 'price': 1859, 'quantity': 8},
#   {'timestamp': 10300, 'price': 1860, 'quantity': -1},
#   {'timestamp': 10300, 'price': 1858, 'quantity': -7},
#   {'timestamp': 10500, 'price': 1859, 'quantity': 6},
#   {'timestamp': 10600, 'price': 1858, 'quantity': -6},
#   {'timestamp': 10800, 'price': 1857, 'quantity': 6},
#   {'timestamp': 10800, 'price': 1859, 'quantity': 2},
#   {'timestamp': 11000, 'price': 1864, 'quantity': -2},
#   {'timestamp': 11000, 'price': 1863, 'quantity': -14},
#   {'timestamp': 11100, 'price': 1865, 'quantity': -2},
#   {'timestamp': 11100, 'price': 1864, 'quantity': -32},
#   {'timestamp': 11300, 'price': 1862, 'quantity': -44},
#   {'timestamp': 11500, 'price': 1858, 'quantity': 10},
#   {'timestamp': 12000, 'price': 1858, 'quantity': 11},
#   {'timestamp': 12100, 'price': 1856, 'quantity': 25},
#   {'timestamp': 12100, 'price': 1854, 'quantity': -1},
#   {'timestamp': 12100, 'price': 1853, 'quantity': -24},
#   {'timestamp': 12500, 'price': 1858, 'quantity': -6},
#   {'timestamp': 12500, 'price': 1857, 'quantity': -16},
#   {'timestamp': 12600, 'price': 1859, 'quantity': -8},
#   {'timestamp': 12600, 'price': 1858, 'quantity': -26},
#   {'timestamp': 13200, 'price': 1853, 'quantity': 33},
#   {'timestamp': 13500, 'price': 1853, 'quantity': -41},
#   {'timestamp': 13600, 'price': 1851, 'quantity': 6},
#   {'timestamp': 13600, 'price': 1852, 'quantity': 4},
#   {'timestamp': 13700, 'price': 1850, 'quantity': 28},
#   {'timestamp': 13700, 'price': 1847, 'quantity': -28},
#   {'timestamp': 13800, 'price': 1850, 'quantity': 23},
#   {'timestamp': 14000, 'price': 1853, 'quantity': 1},
#   {'timestamp': 14000, 'price': 1852, 'quantity': -6},
#   {'timestamp': 14100, 'price': 1852, 'quantity': 9},
#   {'timestamp': 14100, 'price': 1851, 'quantity': -6},
#   {'timestamp': 14200, 'price': 1852, 'quantity': -27},
#   {'timestamp': 14400, 'price': 1853, 'quantity': -22},
#   {'timestamp': 14500, 'price': 1853, 'quantity': 12},
#   {'timestamp': 14500, 'price': 1855, 'quantity': 29},
#   {'timestamp': 14500, 'price': 1852, 'quantity': -2},
#   {'timestamp': 14600, 'price': 1849, 'quantity': 6},
#   {'timestamp': 14600, 'price': 1851, 'quantity': 28},
#   {'timestamp': 14700, 'price': 1852, 'quantity': 4},
#   {'timestamp': 14700, 'price': 1853, 'quantity': 6},
#   {'timestamp': 14700, 'price': 1850, 'quantity': -7},
#   {'timestamp': 14900, 'price': 1854, 'quantity': 41},
#   {'timestamp': 14900, 'price': 1853, 'quantity': -8},
#   {'timestamp': 15400, 'price': 1850, 'quantity': 8},
#   {'timestamp': 15600, 'price': 1849, 'quantity': 26},
#   {'timestamp': 15600, 'price': 1846, 'quantity': -29},
#   {'timestamp': 15700, 'price': 1849, 'quantity': 2},
#   {'timestamp': 15700, 'price': 1850, 'quantity': 20},
#   {'timestamp': 15900, 'price': 1853, 'quantity': -21},
#   {'timestamp': 16000, 'price': 1856, 'quantity': -23},
#   {'timestamp': 16100, 'price': 1856, 'quantity': -43},
#   {'timestamp': 16700, 'price': 1845, 'quantity': 11},
#   {'timestamp': 16800, 'price': 1840, 'quantity': 27},
#   {'timestamp': 16800, 'price': 1838, 'quantity': -4},
#   {'timestamp': 16800, 'price': 1837, 'quantity': -23},
#   {'timestamp': 16900, 'price': 1845, 'quantity': 10},
#   {'timestamp': 17000, 'price': 1845, 'quantity': 13},
#   {'timestamp': 17100, 'price': 1849, 'quantity': -27},
#   {'timestamp': 17200, 'price': 1848, 'quantity': -16},
#   {'timestamp': 17300, 'price': 1848, 'quantity': -7},
#   {'timestamp': 17400, 'price': 1850, 'quantity': -2},
#   {'timestamp': 17400, 'price': 1849, 'quantity': -6},
#   {'timestamp': 17400, 'price': 1848, 'quantity': -2},
#   {'timestamp': 17400, 'price': 1847, 'quantity': -34},
#   {'timestamp': 19100, 'price': 1824, 'quantity': 23},
#   {'timestamp': 19200, 'price': 1826, 'quantity': 26},
#   {'timestamp': 19200, 'price': 1824, 'quantity': -1},
#   {'timestamp': 19200, 'price': 1823, 'quantity': -26},
#   {'timestamp': 19300, 'price': 1828, 'quantity': 26},
#   {'timestamp': 19400, 'price': 1829, 'quantity': -20},
#   {'timestamp': 19500, 'price': 1829, 'quantity': 9},
#   {'timestamp': 19600, 'price': 1830, 'quantity': -10},
#   {'timestamp': 19800, 'price': 1828, 'quantity': 21},
#   {'timestamp': 19900, 'price': 1829, 'quantity': 2},
#   {'timestamp': 19900, 'price': 1830, 'quantity': 6},
#   {'timestamp': 19900, 'price': 1826, 'quantity': -6},
#   {'timestamp': 20100, 'price': 1834, 'quantity': 8},
#   {'timestamp': 20100, 'price': 1835, 'quantity': 2},
#   {'timestamp': 20100, 'price': 1832, 'quantity': -12},
#   {'timestamp': 20200, 'price': 1833, 'quantity': -16},
#   {'timestamp': 20400, 'price': 1831, 'quantity': 6},
#   {'timestamp': 20400, 'price': 1833, 'quantity': 11},
#   {'timestamp': 20700, 'price': 1836, 'quantity': 10},
#   {'timestamp': 20700, 'price': 1837, 'quantity': -4},
#   {'timestamp': 20700, 'price': 1835, 'quantity': -5},
#   {'timestamp': 20800, 'price': 1840, 'quantity': -1},
#   {'timestamp': 20800, 'price': 1839, 'quantity': -34},
#   {'timestamp': 20900, 'price': 1837, 'quantity': -8},
#   {'timestamp': 21100, 'price': 1836, 'quantity': 4},
#   {'timestamp': 21100, 'price': 1838, 'quantity': 4},
#   {'timestamp': 21200, 'price': 1837, 'quantity': 11},
#   {'timestamp': 21300, 'price': 1835, 'quantity': 4},
#   {'timestamp': 21300, 'price': 1836, 'quantity': 12},
#   {'timestamp': 21400, 'price': 1838, 'quantity': 8},
#   {'timestamp': 22100, 'price': 1848, 'quantity': -10},
#   {'timestamp': 22200, 'price': 1850, 'quantity': -3},
#   {'timestamp': 22200, 'price': 1849, 'quantity': -27},
#   {'timestamp': 22300, 'price': 1848, 'quantity': -22},
#   {'timestamp': 22400, 'price': 1846, 'quantity': -12},
#   {'timestamp': 22600, 'price': 1851, 'quantity': -2},
#   {'timestamp': 22600, 'price': 1850, 'quantity': -7},
#   {'timestamp': 22600, 'price': 1849, 'quantity': -30},
#   {'timestamp': 23300, 'price': 1844, 'quantity': 23},
#   {'timestamp': 23400, 'price': 1841, 'quantity': 15},
#   {'timestamp': 23400, 'price': 1843, 'quantity': 1},
#   {'timestamp': 23400, 'price': 1840, 'quantity': -30},
#   {'timestamp': 23500, 'price': 1844, 'quantity': 8},
#   {'timestamp': 23700, 'price': 1846, 'quantity': -2},
#   {'timestamp': 23700, 'price': 1844, 'quantity': -10},
#   {'timestamp': 23800, 'price': 1846, 'quantity': 12},
#   {'timestamp': 23900, 'price': 1846, 'quantity': 7},
#   {'timestamp': 24000, 'price': 1846, 'quantity': -1},
#   {'timestamp': 24000, 'price': 1845, 'quantity': -17},
#   {'timestamp': 24100, 'price': 1844, 'quantity': 23},
#   {'timestamp': 24200, 'price': 1849, 'quantity': -1},
#   {'timestamp': 24200, 'price': 1848, 'quantity': -11},
#   {'timestamp': 24500, 'price': 1845, 'quantity': 9},
#   {'timestamp': 24500, 'price': 1847, 'quantity': 1},
#   {'timestamp': 25000, 'price': 1852, 'quantity': -7},
#   {'timestamp': 25200, 'price': 1852, 'quantity': 8},
#   {'timestamp': 25300, 'price': 1854, 'quantity': -26},
#   {'timestamp': 25500, 'price': 1852, 'quantity': -18},
#   {'timestamp': 25600, 'price': 1853, 'quantity': -31},
#   {'timestamp': 25700, 'price': 1852, 'quantity': 12},
#   {'timestamp': 26000, 'price': 1850, 'quantity': 13},
#   {'timestamp': 26000, 'price': 1852, 'quantity': 33},
#   {'timestamp': 26000, 'price': 1851, 'quantity': -2},
#   {'timestamp': 26700, 'price': 1847, 'quantity': 27},
#   {'timestamp': 26700, 'price': 1846, 'quantity': -2},
#   {'timestamp': 26700, 'price': 1845, 'quantity': -23},
#   {'timestamp': 26800, 'price': 1847, 'quantity': 19},
#   {'timestamp': 26900, 'price': 1849, 'quantity': 8},
#   {'timestamp': 27200, 'price': 1853, 'quantity': -2},
#   {'timestamp': 27200, 'price': 1851, 'quantity': -21},
#   {'timestamp': 27300, 'price': 1850, 'quantity': -6},
#   {'timestamp': 27500, 'price': 1851, 'quantity': 12},
#   {'timestamp': 27800, 'price': 1851, 'quantity': 6},
#   {'timestamp': 27900, 'price': 1850, 'quantity': 11},
#   {'timestamp': 28000, 'price': 1849, 'quantity': -10},
#   {'timestamp': 28100, 'price': 1851, 'quantity': 5},
#   {'timestamp': 28200, 'price': 1850, 'quantity': -17},
#   {'timestamp': 28200, 'price': 1849, 'quantity': -3},
#   {'timestamp': 28500, 'price': 1850, 'quantity': 8},
#   {'timestamp': 28600, 'price': 1849, 'quantity': 10},
#   {'timestamp': 28800, 'price': 1851, 'quantity': 8},
#   {'timestamp': 29600, 'price': 1853, 'quantity': -32},
#   {'timestamp': 29700, 'price': 1852, 'quantity': 10},
#   {'timestamp': 29800, 'price': 1855, 'quantity': -2},
#   {'timestamp': 29800, 'price': 1853, 'quantity': -26},
#   {'timestamp': 29900, 'price': 1856, 'quantity': -15},
#   {'timestamp': 29900, 'price': 1854, 'quantity': -32},
#   {'timestamp': 32900, 'price': 1837, 'quantity': 24},
#   {'timestamp': 33300, 'price': 1836, 'quantity': 31},
#   {'timestamp': 33300, 'price': 1833, 'quantity': -31},
#   {'timestamp': 33400, 'price': 1835, 'quantity': 4},
#   {'timestamp': 33400, 'price': 1836, 'quantity': 23},
#   {'timestamp': 34000, 'price': 1848, 'quantity': -2},
#   {'timestamp': 34000, 'price': 1846, 'quantity': -14},
#   {'timestamp': 34200, 'price': 1847, 'quantity': -34},
#   {'timestamp': 34600, 'price': 1848, 'quantity': -14},
#   {'timestamp': 34600, 'price': 1846, 'quantity': -24},
#   {'timestamp': 35900, 'price': 1842, 'quantity': 4},
#   {'timestamp': 35900, 'price': 1843, 'quantity': 27},
#   {'timestamp': 36000, 'price': 1842, 'quantity': 4},
#   {'timestamp': 36000, 'price': 1843, 'quantity': 2},
#   {'timestamp': 36000, 'price': 1844, 'quantity': 29},
#   {'timestamp': 36000, 'price': 1842, 'quantity': -5},
#   {'timestamp': 36000, 'price': 1841, 'quantity': -30},
#   {'timestamp': 36100, 'price': 1843, 'quantity': 12},
#   {'timestamp': 36100, 'price': 1844, 'quantity': 8},
#   {'timestamp': 36500, 'price': 1843, 'quantity': -14},
#   {'timestamp': 36600, 'price': 1842, 'quantity': 4},
#   {'timestamp': 36600, 'price': 1844, 'quantity': 22},
#   {'timestamp': 36700, 'price': 1845, 'quantity': 11},
#   {'timestamp': 36900, 'price': 1845, 'quantity': -22},
#   {'timestamp': 37000, 'price': 1844, 'quantity': -16},
#   {'timestamp': 37100, 'price': 1846, 'quantity': -9},
#   {'timestamp': 37100, 'price': 1845, 'quantity': -10},
#   {'timestamp': 37100, 'price': 1844, 'quantity': -24},
#   {'timestamp': 37300, 'price': 1842, 'quantity': 8},
#   {'timestamp': 37300, 'price': 1843, 'quantity': 25},
#   {'timestamp': 37300, 'price': 1840, 'quantity': -33},
#   {'timestamp': 37400, 'price': 1845, 'quantity': 6},
#   {'timestamp': 37600, 'price': 1846, 'quantity': 9},
#   {'timestamp': 37600, 'price': 1847, 'quantity': 2},
#   {'timestamp': 37600, 'price': 1845, 'quantity': -6},
#   {'timestamp': 37700, 'price': 1847, 'quantity': 8},
#   {'timestamp': 38700, 'price': 1850, 'quantity': -8},
#   {'timestamp': 38900, 'price': 1851, 'quantity': -37},
#   {'timestamp': 39000, 'price': 1852, 'quantity': -1},
#   {'timestamp': 39000, 'price': 1851, 'quantity': -5},
#   {'timestamp': 39100, 'price': 1853, 'quantity': 30},
#   {'timestamp': 39100, 'price': 1852, 'quantity': -1},
#   {'timestamp': 39200, 'price': 1850, 'quantity': 8},
#   {'timestamp': 39500, 'price': 1849, 'quantity': 6},
#   {'timestamp': 39500, 'price': 1851, 'quantity': 3},
#   {'timestamp': 39700, 'price': 1850, 'quantity': 12},
#   {'timestamp': 39700, 'price': 1852, 'quantity': 17},
#   {'timestamp': 39700, 'price': 1849, 'quantity': -29},
#   {'timestamp': 39900, 'price': 1851, 'quantity': 11},
#   {'timestamp': 40000, 'price': 1850, 'quantity': 14},
#   {'timestamp': 40000, 'price': 1852, 'quantity': 6},
#   {'timestamp': 40200, 'price': 1854, 'quantity': 6},
#   {'timestamp': 40400, 'price': 1852, 'quantity': -6},
#   {'timestamp': 40500, 'price': 1854, 'quantity': 6},
#   {'timestamp': 41000, 'price': 1852, 'quantity': -5},
#   {'timestamp': 41100, 'price': 1854, 'quantity': 6},
#   {'timestamp': 41300, 'price': 1857, 'quantity': -7},
#   {'timestamp': 41300, 'price': 1856, 'quantity': -37},
#   {'timestamp': 41400, 'price': 1858, 'quantity': 18},
#   {'timestamp': 41400, 'price': 1855, 'quantity': -15},
#   {'timestamp': 41500, 'price': 1857, 'quantity': 16},
#   {'timestamp': 41600, 'price': 1856, 'quantity': 26},
#   {'timestamp': 41700, 'price': 1859, 'quantity': -4},
#   {'timestamp': 41700, 'price': 1857, 'quantity': -3},
#   {'timestamp': 41900, 'price': 1859, 'quantity': 7},
#   {'timestamp': 42000, 'price': 1858, 'quantity': -1},
#   {'timestamp': 42000, 'price': 1857, 'quantity': -6},
#   {'timestamp': 42100, 'price': 1860, 'quantity': 6},
#   {'timestamp': 42300, 'price': 1860, 'quantity': -19},
#   {'timestamp': 42600, 'price': 1861, 'quantity': 11},
#   {'timestamp': 42800, 'price': 1859, 'quantity': 4},
#   {'timestamp': 42800, 'price': 1861, 'quantity': 4},
#   {'timestamp': 43000, 'price': 1864, 'quantity': -39},
#   {'timestamp': 43100, 'price': 1865, 'quantity': -2},
#   {'timestamp': 43100, 'price': 1864, 'quantity': -34},
#   {'timestamp': 43200, 'price': 1863, 'quantity': -8},
#   {'timestamp': 43400, 'price': 1863, 'quantity': 42},
#   {'timestamp': 43400, 'price': 1860, 'quantity': -24},
#   {'timestamp': 43500, 'price': 1861, 'quantity': -48},
#   {'timestamp': 51400, 'price': 1831, 'quantity': 8},
#   {'timestamp': 51600, 'price': 1831, 'quantity': 7},
#   {'timestamp': 52000, 'price': 1830, 'quantity': 8},
#   {'timestamp': 52100, 'price': 1830, 'quantity': 28},
#   {'timestamp': 52100, 'price': 1827, 'quantity': -28},
#   {'timestamp': 52200, 'price': 1830, 'quantity': 10},
#   {'timestamp': 52300, 'price': 1831, 'quantity': 15},
#   {'timestamp': 53000, 'price': 1840, 'quantity': -1},
#   {'timestamp': 53000, 'price': 1839, 'quantity': -7},
#   {'timestamp': 53200, 'price': 1841, 'quantity': 6},
#   {'timestamp': 53300, 'price': 1840, 'quantity': -5},
#   {'timestamp': 53400, 'price': 1843, 'quantity': 4},
#   {'timestamp': 53400, 'price': 1841, 'quantity': -14},
#   {'timestamp': 53500, 'price': 1840, 'quantity': -14},
#   {'timestamp': 53700, 'price': 1841, 'quantity': -11},
#   {'timestamp': 53700, 'price': 1840, 'quantity': -29},
#   {'timestamp': 53900, 'price': 1839, 'quantity': 8},
#   {'timestamp': 54000, 'price': 1840, 'quantity': 11},
#   {'timestamp': 54100, 'price': 1841, 'quantity': 25},
#   {'timestamp': 54100, 'price': 1840, 'quantity': -2},
#   {'timestamp': 54500, 'price': 1838, 'quantity': 22},
#   {'timestamp': 54500, 'price': 1836, 'quantity': -8},
#   {'timestamp': 54500, 'price': 1835, 'quantity': -22},
#   {'timestamp': 54600, 'price': 1839, 'quantity': 14},
#   {'timestamp': 54700, 'price': 1842, 'quantity': 6},
#   {'timestamp': 54800, 'price': 1840, 'quantity': -32},
#   {'timestamp': 55100, 'price': 1839, 'quantity': -9},
#   {'timestamp': 55300, 'price': 1838, 'quantity': 6},
#   {'timestamp': 55300, 'price': 1839, 'quantity': 13},
#   {'timestamp': 55400, 'price': 1839, 'quantity': 21},
#   {'timestamp': 55500, 'price': 1840, 'quantity': -18},
#   {'timestamp': 55600, 'price': 1840, 'quantity': -19},
#   {'timestamp': 55700, 'price': 1840, 'quantity': -11},
#   {'timestamp': 55800, 'price': 1839, 'quantity': -50},
#   {'timestamp': 56000, 'price': 1838, 'quantity': 10},
#   {'timestamp': 56200, 'price': 1835, 'quantity': 8},
#   {'timestamp': 56200, 'price': 1837, 'quantity': 31},
#   {'timestamp': 56200, 'price': 1834, 'quantity': -31},
#   {'timestamp': 56500, 'price': 1839, 'quantity': 20},
#   {'timestamp': 57200, 'price': 1847, 'quantity': -26},
#   {'timestamp': 57300, 'price': 1847, 'quantity': -23},
#   {'timestamp': 57400, 'price': 1846, 'quantity': -44},
#   {'timestamp': 58200, 'price': 1840, 'quantity': 29},
#   {'timestamp': 58300, 'price': 1840, 'quantity': 30},
#   {'timestamp': 58300, 'price': 1836, 'quantity': -30},
#   {'timestamp': 58400, 'price': 1840, 'quantity': 25},
#   {'timestamp': 58500, 'price': 1841, 'quantity': -22},
#   {'timestamp': 58600, 'price': 1840, 'quantity': -39},
#   {'timestamp': 58700, 'price': 1839, 'quantity': 8},
#   {'timestamp': 58700, 'price': 1838, 'quantity': -2},
#   {'timestamp': 58800, 'price': 1839, 'quantity': 10},
#   {'timestamp': 58800, 'price': 1840, 'quantity': -1},
#   {'timestamp': 58800, 'price': 1839, 'quantity': -1},
#   {'timestamp': 58800, 'price': 1837, 'quantity': -33},
#   {'timestamp': 58900, 'price': 1842, 'quantity': 10},
#   {'timestamp': 59000, 'price': 1842, 'quantity': 7},
#   {'timestamp': 59200, 'price': 1843, 'quantity': 6},
#   {'timestamp': 59200, 'price': 1842, 'quantity': -13},
#   {'timestamp': 59500, 'price': 1844, 'quantity': 6},
#   {'timestamp': 59600, 'price': 1842, 'quantity': -1},
#   {'timestamp': 59600, 'price': 1841, 'quantity': -5},
#   {'timestamp': 59700, 'price': 1843, 'quantity': 6},
#   {'timestamp': 59700, 'price': 1844, 'quantity': -2},
#   {'timestamp': 59800, 'price': 1843, 'quantity': -20},
#   {'timestamp': 59900, 'price': 1845, 'quantity': -27},
#   {'timestamp': 60100, 'price': 1845, 'quantity': -28},
#   {'timestamp': 60300, 'price': 1842, 'quantity': 6},
#   {'timestamp': 60400, 'price': 1842, 'quantity': 24},
#   {'timestamp': 60400, 'price': 1839, 'quantity': -24},
#   {'timestamp': 60700, 'price': 1842, 'quantity': -10},
#   {'timestamp': 61500, 'price': 1844, 'quantity': -2},
#   {'timestamp': 61500, 'price': 1842, 'quantity': -10},
#   {'timestamp': 61600, 'price': 1844, 'quantity': -44},
#   {'timestamp': 62900, 'price': 1837, 'quantity': 25},
#   {'timestamp': 63400, 'price': 1837, 'quantity': 18},
#   {'timestamp': 63600, 'price': 1839, 'quantity': 44},
#   {'timestamp': 63600, 'price': 1838, 'quantity': -2},
#   {'timestamp': 64000, 'price': 1834, 'quantity': 47},
#   {'timestamp': 64000, 'price': 1831, 'quantity': -34},
#   {'timestamp': 64100, 'price': 1835, 'quantity': 8},
#   {'timestamp': 64100, 'price': 1837, 'quantity': 1},
#   {'timestamp': 64300, 'price': 1836, 'quantity': 12},
#   {'timestamp': 64700, 'price': 1839, 'quantity': -45},
#   {'timestamp': 64900, 'price': 1841, 'quantity': 43},
#   {'timestamp': 64900, 'price': 1838, 'quantity': -48},
#   {'timestamp': 65000, 'price': 1842, 'quantity': 40},
#   {'timestamp': 65000, 'price': 1841, 'quantity': -2},
#   {'timestamp': 67200, 'price': 1835, 'quantity': 10},
#   {'timestamp': 67700, 'price': 1832, 'quantity': 6},
#   {'timestamp': 67700, 'price': 1834, 'quantity': 23},
#   {'timestamp': 67700, 'price': 1831, 'quantity': -29},
#   {'timestamp': 67900, 'price': 1835, 'quantity': 23},
#   {'timestamp': 68200, 'price': 1838, 'quantity': 6},
#   {'timestamp': 68200, 'price': 1836, 'quantity': -1},
#   {'timestamp': 68200, 'price': 1835, 'quantity': -5},
#   {'timestamp': 68600, 'price': 1838, 'quantity': -32},
#   {'timestamp': 68700, 'price': 1838, 'quantity': -11},
#   {'timestamp': 68800, 'price': 1838, 'quantity': 11},
#   {'timestamp': 68900, 'price': 1838, 'quantity': 25},
#   {'timestamp': 69100, 'price': 1838, 'quantity': 1},
#   {'timestamp': 69100, 'price': 1840, 'quantity': 6},
#   {'timestamp': 69400, 'price': 1839, 'quantity': -4},
#   {'timestamp': 69400, 'price': 1838, 'quantity': -2},
#   {'timestamp': 70300, 'price': 1841, 'quantity': 6},
#   {'timestamp': 70600, 'price': 1840, 'quantity': -4},
#   {'timestamp': 70600, 'price': 1839, 'quantity': -13},
#   {'timestamp': 71000, 'price': 1838, 'quantity': 2},
#   {'timestamp': 71000, 'price': 1840, 'quantity': 6},
#   {'timestamp': 71100, 'price': 1840, 'quantity': 8},
#   {'timestamp': 71200, 'price': 1838, 'quantity': -7},
#   {'timestamp': 71400, 'price': 1839, 'quantity': 12},
#   {'timestamp': 71400, 'price': 1838, 'quantity': -4},
#   {'timestamp': 71700, 'price': 1844, 'quantity': 1},
#   {'timestamp': 71700, 'price': 1844, 'quantity': -2},
#   {'timestamp': 72000, 'price': 1844, 'quantity': -6},
#   {'timestamp': 72200, 'price': 1844, 'quantity': -36},
#   {'timestamp': 72600, 'price': 1844, 'quantity': -7},
#   {'timestamp': 72700, 'price': 1845, 'quantity': -44},
#   {'timestamp': 74400, 'price': 1832, 'quantity': 4},
#   {'timestamp': 74400, 'price': 1833, 'quantity': 2},
#   {'timestamp': 74600, 'price': 1832, 'quantity': 1},
#   {'timestamp': 74600, 'price': 1833, 'quantity': 7},
#   {'timestamp': 75000, 'price': 1831, 'quantity': 1},
#   {'timestamp': 75000, 'price': 1833, 'quantity': 27},
#   {'timestamp': 75500, 'price': 1832, 'quantity': 2},
#   {'timestamp': 75500, 'price': 1834, 'quantity': 23},
#   {'timestamp': 75500, 'price': 1831, 'quantity': -25},
#   {'timestamp': 75800, 'price': 1835, 'quantity': 8},
#   {'timestamp': 75800, 'price': 1834, 'quantity': -2},
#   {'timestamp': 75800, 'price': 1832, 'quantity': -8},
#   {'timestamp': 76000, 'price': 1834, 'quantity': -50},
#   {'timestamp': 76900, 'price': 1823, 'quantity': 14},
#   {'timestamp': 77000, 'price': 1817, 'quantity': 8},
#   {'timestamp': 77000, 'price': 1819, 'quantity': 28},
#   {'timestamp': 77000, 'price': 1815, 'quantity': -28},
#   {'timestamp': 77400, 'price': 1825, 'quantity': -10},
#   {'timestamp': 77400, 'price': 1823, 'quantity': -24},
#   {'timestamp': 77500, 'price': 1823, 'quantity': -6},
#   {'timestamp': 77700, 'price': 1822, 'quantity': -47},
#   {'timestamp': 80300, 'price': 1806, 'quantity': 8},
#   {'timestamp': 80600, 'price': 1803, 'quantity': 4},
#   {'timestamp': 80600, 'price': 1804, 'quantity': 40},
#   {'timestamp': 80600, 'price': 1801, 'quantity': -41},
#   {'timestamp': 80800, 'price': 1805, 'quantity': -36},
#   {'timestamp': 80900, 'price': 1806, 'quantity': -40},
#   {'timestamp': 81000, 'price': 1803, 'quantity': 43},
#   {'timestamp': 81000, 'price': 1800, 'quantity': -43},
#   {'timestamp': 81100, 'price': 1805, 'quantity': 9},
#   {'timestamp': 81800, 'price': 1812, 'quantity': -21},
#   {'timestamp': 81900, 'price': 1811, 'quantity': -22},
#   {'timestamp': 82000, 'price': 1812, 'quantity': -6},
#   {'timestamp': 82100, 'price': 1810, 'quantity': -42},
#   {'timestamp': 82500, 'price': 1804, 'quantity': 18},
#   {'timestamp': 82600, 'price': 1804, 'quantity': 24},
#   {'timestamp': 82600, 'price': 1803, 'quantity': -31},
#   {'timestamp': 82700, 'price': 1805, 'quantity': -51},
#   {'timestamp': 82800, 'price': 1804, 'quantity': -21},
#   {'timestamp': 82900, 'price': 1807, 'quantity': 8},
#   {'timestamp': 82900, 'price': 1804, 'quantity': -9},
#   {'timestamp': 83000, 'price': 1806, 'quantity': -41},
#   {'timestamp': 84300, 'price': 1800, 'quantity': 5},
#   {'timestamp': 84500, 'price': 1800, 'quantity': 6},
#   {'timestamp': 84600, 'price': 1798, 'quantity': 30},
#   {'timestamp': 84600, 'price': 1796, 'quantity': -1},
#   {'timestamp': 84600, 'price': 1795, 'quantity': -29},
#   {'timestamp': 84700, 'price': 1802, 'quantity': 13},
#   {'timestamp': 84800, 'price': 1802, 'quantity': 6},
#   {'timestamp': 85300, 'price': 1808, 'quantity': -12},
#   {'timestamp': 85400, 'price': 1808, 'quantity': -6},
#   {'timestamp': 85500, 'price': 1808, 'quantity': 10},
#   {'timestamp': 85500, 'price': 1809, 'quantity': 8},
#   {'timestamp': 85900, 'price': 1813, 'quantity': -18},
#   {'timestamp': 86000, 'price': 1815, 'quantity': -8},
#   {'timestamp': 86000, 'price': 1814, 'quantity': -23},
#   {'timestamp': 86200, 'price': 1814, 'quantity': -44},
#   {'timestamp': 88200, 'price': 1808, 'quantity': 30},
#   {'timestamp': 88300, 'price': 1808, 'quantity': 8},
#   {'timestamp': 88600, 'price': 1807, 'quantity': 8},
#   {'timestamp': 88600, 'price': 1808, 'quantity': 2},
#   {'timestamp': 88600, 'price': 1809, 'quantity': 30},
#   {'timestamp': 88600, 'price': 1806, 'quantity': -45},
#   {'timestamp': 88900, 'price': 1808, 'quantity': -17},
#   {'timestamp': 88900, 'price': 1807, 'quantity': -27},
#   {'timestamp': 89600, 'price': 1806, 'quantity': 9},
#   {'timestamp': 89800, 'price': 1807, 'quantity': 14},
#   {'timestamp': 89900, 'price': 1809, 'quantity': 60},
#   {'timestamp': 89900, 'price': 1808, 'quantity': -1},
#   {'timestamp': 90100, 'price': 1806, 'quantity': 16},
#   {'timestamp': 90100, 'price': 1808, 'quantity': 3},
#   {'timestamp': 90200, 'price': 1805, 'quantity': 12},
#   {'timestamp': 90200, 'price': 1807, 'quantity': 26},
#   {'timestamp': 90200, 'price': 1806, 'quantity': -1},
#   {'timestamp': 90200, 'price': 1804, 'quantity': -3},
#   {'timestamp': 90200, 'price': 1803, 'quantity': -28},
#   {'timestamp': 90300, 'price': 1808, 'quantity': 7},
#   {'timestamp': 90400, 'price': 1807, 'quantity': 8},
#   {'timestamp': 90400, 'price': 1808, 'quantity': 4},
#   {'timestamp': 90500, 'price': 1809, 'quantity': -1},
#   {'timestamp': 90500, 'price': 1808, 'quantity': -16},
#   {'timestamp': 90500, 'price': 1807, 'quantity': -28},
#   {'timestamp': 90700, 'price': 1809, 'quantity': 31},
#   {'timestamp': 90700, 'price': 1808, 'quantity': -1},
#   {'timestamp': 91300, 'price': 1802, 'quantity': 14},
#   {'timestamp': 91300, 'price': 1804, 'quantity': 22},
#   {'timestamp': 91300, 'price': 1800, 'quantity': -26},
#   {'timestamp': 91400, 'price': 1804, 'quantity': 6},
#   {'timestamp': 91600, 'price': 1803, 'quantity': 22},
#   {'timestamp': 92800, 'price': 1814, 'quantity': -9},
#   {'timestamp': 92800, 'price': 1813, 'quantity': -33},
#   {'timestamp': 93100, 'price': 1812, 'quantity': 4},
#   {'timestamp': 93100, 'price': 1814, 'quantity': 4},
#   {'timestamp': 93300, 'price': 1811, 'quantity': 14},
#   {'timestamp': 93300, 'price': 1813, 'quantity': 23},
#   {'timestamp': 93500, 'price': 1817, 'quantity': -10},
#   {'timestamp': 93700, 'price': 1818, 'quantity': -30},
#   {'timestamp': 93800, 'price': 1816, 'quantity': 8},
#   {'timestamp': 94300, 'price': 1815, 'quantity': -10},
#   {'timestamp': 94500, 'price': 1815, 'quantity': 18},
#   {'timestamp': 94600, 'price': 1815, 'quantity': 22},
#   {'timestamp': 94700, 'price': 1819, 'quantity': -2},
#   {'timestamp': 94700, 'price': 1818, 'quantity': -1},
#   {'timestamp': 94700, 'price': 1817, 'quantity': -3},
#   {'timestamp': 94800, 'price': 1816, 'quantity': 2},
#   {'timestamp': 94800, 'price': 1818, 'quantity': 4},
#   {'timestamp': 94900, 'price': 1818, 'quantity': -30},
#   {'timestamp': 95500, 'price': 1815, 'quantity': 6},
#   {'timestamp': 95500, 'price': 1816, 'quantity': 3},
#   {'timestamp': 95600, 'price': 1816, 'quantity': 5},
#   {'timestamp': 95800, 'price': 1816, 'quantity': 10},
#   {'timestamp': 96000, 'price': 1816, 'quantity': 9},
#   {'timestamp': 96100, 'price': 1816, 'quantity': -2},
#   {'timestamp': 96100, 'price': 1814, 'quantity': -8},
#   {'timestamp': 96200, 'price': 1817, 'quantity': 8},
#   {'timestamp': 96400, 'price': 1816, 'quantity': 3},
#   {'timestamp': 96400, 'price': 1816, 'quantity': -14},
#   {'timestamp': 96500, 'price': 1815, 'quantity': -10},
#   {'timestamp': 96700, 'price': 1815, 'quantity': 4},
#   {'timestamp': 96700, 'price': 1816, 'quantity': 2},
#   {'timestamp': 96700, 'price': 1817, 'quantity': 3},
#   {'timestamp': 96800, 'price': 1816, 'quantity': 8},
#   {'timestamp': 97100, 'price': 1815, 'quantity': -20},
#   {'timestamp': 97300, 'price': 1815, 'quantity': 21},
#   {'timestamp': 97400, 'price': 1816, 'quantity': -2},
#   {'timestamp': 97400, 'price': 1814, 'quantity': -6},
#   {'timestamp': 97500, 'price': 1816, 'quantity': 12},
#   {'timestamp': 97600, 'price': 1816, 'quantity': -8},
#   {'timestamp': 97600, 'price': 1815, 'quantity': -1},
#   {'timestamp': 97700, 'price': 1815, 'quantity': -14},
#   {'timestamp': 98200, 'price': 1815, 'quantity': 6},
#   {'timestamp': 98200, 'price': 1817, 'quantity': 4},
#   {'timestamp': 98300, 'price': 1816, 'quantity': 6},
#   {'timestamp': 98300, 'price': 1818, 'quantity': 1},
#   {'timestamp': 98300, 'price': 1815, 'quantity': -8},
#   {'timestamp': 98400, 'price': 1815, 'quantity': -31},
#   {'timestamp': 98500, 'price': 1816, 'quantity': -32},
#   {'timestamp': 99000, 'price': 1812, 'quantity': 28},
#   {'timestamp': 99000, 'price': 1810, 'quantity': -1},
#   {'timestamp': 99000, 'price': 1809, 'quantity': -27},
#   {'timestamp': 99100, 'price': 1814, 'quantity': 6},
#   {'timestamp': 99200, 'price': 1812, 'quantity': 2},
#   {'timestamp': 99200, 'price': 1814, 'quantity': 12},
#   {'timestamp': 99300, 'price': 1816, 'quantity': 6},
#   {'timestamp': 99300, 'price': 1814, 'quantity': -2},
#   {'timestamp': 99300, 'price': 1813, 'quantity': -2},
#   {'timestamp': 99300, 'price': 1812, 'quantity': -2},
#   {'timestamp': 99600, 'price': 1817, 'quantity': -10},
#   {'timestamp': 99900, 'price': 1819, 'quantity': 39},
#   {'timestamp': 99900, 'price': 1816, 'quantity': -43}]}

# %%
kelp_trades = pd.DataFrame(results['SQUID_INK']['trades'])
kelp_trades['string'] = kelp_trades.apply(lambda row: f"{row['timestamp']},{row['price']},{row['quantity']}", axis=1)
kelp = ";".join(kelp_trades['string'])

# %%
kelp
# Out:
# '100,1837,-2;100,1836,-2;100,1835,-2;300,1837,37;300,1836,-2;400,1836,7;500,1834,-6;600,1833,14;600,1834,-10;600,1832,-36;700,1837,2;700,1838,4;1400,1842,9;1400,1841,-9;1500,1844,-2;1500,1842,-5;1600,1844,-4;1600,1843,-28;1700,1843,16;1700,1844,17;1800,1845,6;2000,1846,-13;2100,1847,10;2300,1848,-7;2400,1849,10;2600,1850,-1;2600,1849,-22;2700,1851,12;2800,1849,-7;2900,1851,10;3200,1849,8;4100,1857,6;4100,1855,-10;4200,1854,-7;4500,1854,10;4600,1858,6;4600,1860,1;4600,1857,-7;4800,1861,-2;4800,1860,-7;4800,1859,-23;4900,1859,9;5000,1860,-12;5000,1859,-9;5300,1860,20;5400,1860,8;5500,1859,11;5600,1860,-5;5600,1859,-3;5900,1860,12;6100,1862,6;6100,1859,-6;6200,1861,-2;6200,1859,-6;6300,1861,-9;6500,1860,-10;6600,1860,-22;6700,1861,14;6700,1862,31;6700,1861,-1;9100,1858,6;9300,1857,12;9500,1856,26;9500,1854,-1;9500,1853,-25;9700,1856,10;9700,1857,5;9700,1858,8;9900,1858,-6;10100,1859,8;10300,1860,-1;10300,1858,-7;10500,1859,6;10600,1858,-6;10800,1857,6;10800,1859,2;11000,1864,-2;11000,1863,-14;11100,1865,-2;11100,1864,-32;11300,1862,-44;11500,1858,10;12000,1858,11;12100,1856,25;12100,1854,-1;12100,1853,-24;12500,1858,-6;12500,1857,-16;12600,1859,-8;12600,1858,-26;13200,1853,33;13500,1853,-41;13600,1851,6;13600,1852,4;13700,1850,28;13700,1847,-28;13800,1850,23;14000,1853,1;14000,1852,-6;14100,1852,9;14100,1851,-6;14200,1852,-27;14400,1853,-22;14500,1853,12;14500,1855,29;14500,1852,-2;14600,1849,6;14600,1851,28;14700,1852,4;14700,1853,6;14700,1850,-7;14900,1854,41;14900,1853,-8;15400,1850,8;15600,1849,26;15600,1846,-29;15700,1849,2;15700,1850,20;15900,1853,-21;16000,1856,-23;16100,1856,-43;16700,1845,11;16800,1840,27;16800,1838,-4;16800,1837,-23;16900,1845,10;17000,1845,13;17100,1849,-27;17200,1848,-16;17300,1848,-7;17400,1850,-2;17400,1849,-6;17400,1848,-2;17400,1847,-34;19100,1824,23;19200,1826,26;19200,1824,-1;19200,1823,-26;19300,1828,26;19400,1829,-20;19500,1829,9;19600,1830,-10;19800,1828,21;19900,1829,2;19900,1830,6;19900,1826,-6;20100,1834,8;20100,1835,2;20100,1832,-12;20200,1833,-16;20400,1831,6;20400,1833,11;20700,1836,10;20700,1837,-4;20700,1835,-5;20800,1840,-1;20800,1839,-34;20900,1837,-8;21100,1836,4;21100,1838,4;21200,1837,11;21300,1835,4;21300,1836,12;21400,1838,8;22100,1848,-10;22200,1850,-3;22200,1849,-27;22300,1848,-22;22400,1846,-12;22600,1851,-2;22600,1850,-7;22600,1849,-30;23300,1844,23;23400,1841,15;23400,1843,1;23400,1840,-30;23500,1844,8;23700,1846,-2;23700,1844,-10;23800,1846,12;23900,1846,7;24000,1846,-1;24000,1845,-17;24100,1844,23;24200,1849,-1;24200,1848,-11;24500,1845,9;24500,1847,1;25000,1852,-7;25200,1852,8;25300,1854,-26;25500,1852,-18;25600,1853,-31;25700,1852,12;26000,1850,13;26000,1852,33;26000,1851,-2;26700,1847,27;26700,1846,-2;26700,1845,-23;26800,1847,19;26900,1849,8;27200,1853,-2;27200,1851,-21;27300,1850,-6;27500,1851,12;27800,1851,6;27900,1850,11;28000,1849,-10;28100,1851,5;28200,1850,-17;28200,1849,-3;28500,1850,8;28600,1849,10;28800,1851,8;29600,1853,-32;29700,1852,10;29800,1855,-2;29800,1853,-26;29900,1856,-15;29900,1854,-32;32900,1837,24;33300,1836,31;33300,1833,-31;33400,1835,4;33400,1836,23;34000,1848,-2;34000,1846,-14;34200,1847,-34;34600,1848,-14;34600,1846,-24;35900,1842,4;35900,1843,27;36000,1842,4;36000,1843,2;36000,1844,29;36000,1842,-5;36000,1841,-30;36100,1843,12;36100,1844,8;36500,1843,-14;36600,1842,4;36600,1844,22;36700,1845,11;36900,1845,-22;37000,1844,-16;37100,1846,-9;37100,1845,-10;37100,1844,-24;37300,1842,8;37300,1843,25;37300,1840,-33;37400,1845,6;37600,1846,9;37600,1847,2;37600,1845,-6;37700,1847,8;38700,1850,-8;38900,1851,-37;39000,1852,-1;39000,1851,-5;39100,1853,30;39100,1852,-1;39200,1850,8;39500,1849,6;39500,1851,3;39700,1850,12;39700,1852,17;39700,1849,-29;39900,1851,11;40000,1850,14;40000,1852,6;40200,1854,6;40400,1852,-6;40500,1854,6;41000,1852,-5;41100,1854,6;41300,1857,-7;41300,1856,-37;41400,1858,18;41400,1855,-15;41500,1857,16;41600,1856,26;41700,1859,-4;41700,1857,-3;41900,1859,7;42000,1858,-1;42000,1857,-6;42100,1860,6;42300,1860,-19;42600,1861,11;428 ...
